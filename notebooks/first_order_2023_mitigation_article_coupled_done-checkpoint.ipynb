# %% [markdown]
# # Equation
# # $$ \dot{v} (t)= g$$
#
# ## Initial condition:
# # $$v(0) = 0$$
#
# # Solutions
# # $$v(t) = gt t$$
# # $$u(t) = \mbox{Real}z(t) = \cos t$$
# # $$v(t) = \mbox{Im}z(t)   = \sin t$$

# %%
import tensorflow as tf
import numpy as np
from functools import partial
import matplotlib.pyplot as plt
import time
import tensorflow_probability as tfp
from tqdm.notebook import tnrange
import seaborn as sns
# Out:
# 2023-01-08 00:52:21.241956: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-08 00:52:21.348017: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-01-08 00:52:21.369166: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-01-08 00:52:21.762022: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64:/home/tshegofatso/miniconda3/envs/tf_38gpu/lib/
# 2023-01-08 00:52:21.762059: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64:/home/tshegofatso/miniconda3/envs/tf_38gpu/lib/
# 2023-01-08 00:52:21.762063: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# from numpy.random import seed
# from tensorflow.random import set_seed

# seed(42)
# set_seed(42)

# %%
tf.__version__
if tf.test.gpu_device_name() != '/device:GPU:0':
    print('WARNING: GPU device not found.')
else:
    print('SUCCESS: Found GPU: {}'.format(tf.test.gpu_device_name()))
# Out:
# WARNING: GPU device not found.
# 2023-01-08 00:52:24.548591: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-08 00:52:25.718100: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2023-01-08 00:52:25.718130: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: tshegofatso-GE76-Raider-11UG
# 2023-01-08 00:52:25.718135: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: tshegofatso-GE76-Raider-11UG
# 2023-01-08 00:52:25.718275: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.141.3
# 2023-01-08 00:52:25.718290: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 470.141.3
# 2023-01-08 00:52:25.718294: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 470.141.3

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(
        gpus[0],[tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])
    except RuntimeError as e:
        print(e)

# %%
class MyDense(tf.keras.layers.Layer):
    '''
    Inputs:
    
    units : number of neurons
    initialization = 0,1
           if activations are:
           init =0(He): ReLU, Leaky ReLU, ELU, GELU, Swish, Mish
           init =1(Xavier_Glorot): None, tanh, sigmoid, softmax 
           
    activation: activation to be use either string or callable
    
    
    Output:
            returns activation(wx+b) with appropriate initialization
    
    '''
    def __init__(self, units = 20, initialization=None, activation = None): #None = gives basic activation
        super(MyDense, self).__init__()
        self.units = units   
        self.init = initialization
        
        if activation == 'mish':
            self.activation = tf.keras.activations.get(self.mish_activation)
        else:
            self.activation = tf.keras.activations.get(activation)
       
    @tf.function
    def mish_activation(self, x):
#         print(f'called_mish')
    #     mish(x) = xtanh(softsplus(x))  it needs  He initialization
        return x*tf.math.tanh(tf.nn.softplus(x))       
    
    
# We get them from the shape of w= shape
# shape[0] : number of inputs to the neuron
# shape[1] : number of output from the neuron
#     @tf.function(reduce_retracing=True)
    def Xavier_Glorot_initializer(self,shape, dtype=tf.float32):
        '''
        Xavier Glorot: initialization must be used for the following activations:
        None, tanh, sigmoid, softmax

       input: 
            shape = [number of columns, units]

       output:
               samples normal distribution of mean = 0 stddev = sqrt(2./inputs_shape+units)
        '''
#         print('Initial weight with  Xavier Glorot ')
        
        shape_to_float = tf.cast(shape, dtype=tf.float32)
        fanin = shape_to_float[0]
        fanout = shape_to_float[1]
        stddev = tf.sqrt(2. /(fanin+fanout)  )
        return tf.random.normal(shape, stddev=stddev, dtype=dtype)
    
#     @tf.function(reduce_retracing=True) 
    def He_initializer(self,shape,dtype = tf.float32):
        '''
        input: 
                shape = [number of columns, units]

        He (aka He normal)initialization must be used for the following activations:
        ReLU, Leaky ReLU, ELU, GELU, Swish, Mish

        He initialization:
        random normal with variance and mean of 2/fanin = 2/no. of inputs = 2/inputs
        '''
        shape_to_float = tf.cast(shape, dtype=tf.float32)
#         print(f'INIT shape = {shape}, dtype = {shape.dtype}')
#         fanin = tf.constant(shape[0], dtype = tf.float32)
        fanin = shape_to_float[0]
#         print(f'fanin = {fanin}')
        stddev = tf.sqrt(2. /fanin)
#         print(f'stddev = {stddev}')
#         print('Initial weight with  He')
        return tf.random.normal(shape, stddev=stddev, dtype=dtype)        

#     Initialize kernel aka w
    def init_w(self, input_shape):
        shape = [input_shape[-1], self.units]
        shape = tf.constant(shape, dtype=tf.int32)

        if self.init == 0:
#             Initialize with He : Relu and variants activation functions
            value = self.He_initializer(shape)
        else:
#             Initialize with Xavier_Glorot : None, tanh, sigmoid, softmax activation functions
            value = self.Xavier_Glorot_initializer(shape)
            
        return tf.Variable(name = 'kernel', initial_value=value ,trainable = True )

#     Initialize biase aka b
    def init_b(self):
#         value = tf.zeros(self.units)  # originsl
        value = tf.ones(self.units)
        return tf.Variable(name = 'bias', initial_value=value ,trainable = True )    
       
        
    def build(self, input_shape):
        self.w = self.init_w(input_shape)
        self.b = self.init_b()
        
    def call(self, inputs):
        out_put = self.activation(tf.matmul(inputs, self.w) + self.b)
        return out_put
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "weight": self.w,
            "biase": self.b,
            })
        return config

# %%
class Z_approx(tf.keras.Model):
    def __init__(self,v0,rhs,num_of_hid_layers = None, units_per_layer = None, num_out=1, initialization=None, activation=None):
        super(Z_approx,self).__init__()
        self.num_of_hid_layers = num_of_hid_layers
        self.units_per_layer = units_per_layer
        self.num_out = num_out
        self.init = initialization
        self.normalize = tf.keras.layers.Normalization()
        self.v0 = v0
        self.rhs = rhs

        if self.init == 0:
            kerner_init = tf.keras.initializers.he_normal()
        else:
            kerner_init = tf.keras.initializers.glorot_normal()
            
        
        
        
        self.initialization = initialization
        self.activation = activation
        
        
        
        self.hidden_layers = [MyDense(self.units_per_layer, self.initialization, self.activation) 
                              for _ in range(self.num_of_hid_layers)]
        
        self.out = MyDense(units=self.num_out, initialization=self.initialization)
        
        self.bn = [tf.keras.layers.BatchNormalization() for _ in range(self.num_of_hid_layers)]
    
    def call(self, inputs):
        '''
        Add BN before since the layer includes activations
        
        '''
        for i in range(self.num_of_hid_layers):
            if i == 0:
                x = self.normalize(inputs)
                x = self.bn[i](x)
            else:
                x = self.bn[i](x)
                
            x = self.hidden_layers[i](x)
        return self.out(x)     
    
    def pinn_net(self,t):
        with tf.GradientTape(persistent=True) as tape:
            tape.watch(t)         
            z_real = self.call(t)[:,0:1]
            z_imag = self.call(t)[:,1:2]
        dz_realdt = tf.cast(tape.gradient(z_real,t),dtype=tf.float32)
        dz_imagdt = tf.cast(tape.gradient(z_imag,t),dtype=tf.float32)  
        del tape
        
        'Im here!'
        
        residue_pde = dvdt - self.rhs
        residue_ic  = self.v0 - self.call(t[0])

        return z_real,z_imag, dz_realdt,dz_imagdt
        
        
        
        
        
        with tf.GradientTape() as tape:
            tape.watch(t)         
            v = self.call(t)
        dvdt = tf.cast(tape.gradient(v,t),dtype=tf.float32) 
        
        residue_pde = dvdt - self.rhs
        residue_ic  = self.v0 - self.call(t[0])
        
        return residue_pde, residue_ic
        
        
    @tf.function    
    def loss(self,t):
        residue_pde, residue_ic = self.pinn_net(t)
        loss_pde = tf.reduce_mean(tf.square(residue_pde))
        loss_ic = tf.reduce_mean(tf.square(residue_ic))
        return loss_pde,loss_ic
    
    
    def get_config(self):
        weights_l = []
        biases_l = []
        config = super().get_config()
        config.update({
            "weight": self.w,
            "biase": self.b,
            })
        
        return config
    
def calc_imbalance(t):
    with tf.GradientTape(persistent=True) as tape:
        residue_pde, residue_ic = z_hat.loss(t)
    dresidue_pde = tape.gradient(residue_pde,z_hat.trainable_variables)  
    dresidue_ic = tape.gradient(residue_ic,z_hat.trainable_variables)
    
    del tape
    return residue_pde, residue_ic,dresidue_pde,dresidue_ic

# %%
t = tf.cast(tf.linspace(0,1,50)[:,tf.newaxis],tf.float32)
v0 = tf.constant(0.0, tf.float32)
g = tf.constant(9.8, tf.float32)
rhs = g
#initiazing
z_hat = Z_approx(v0,rhs,num_of_hid_layers = 3, units_per_layer = 30, num_out=1, initialization = 1,activation = tf.nn.tanh)
z_hat.build(t.shape)

z_hat.loss(t)
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=96.27544>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.62155896>)

# %%
# @tf.function
def tensor_to_list(tensor):
    length_shapes = len(tf.shape_n(z_hat.trainable_variables))
    part_list = []
    for i in range(length_shapes):
        part_list.extend(part.read(i).numpy())
    return part_list 

@tf.function
def to_fix(z_hat):
    shapes = tf.shape_n(z_hat.trainable_variables)
    length_shapes = len(shapes)
    count = 0
    idx = []
    part = tf.TensorArray(tf.int32, size=0, dynamic_size=True, clear_after_read=False,infer_shape=False)
    # part = []

#     loss_pde,loss_ic = z_hat.loss(t)
#     total_loss = loss_pde + loss_ic

    for i in range(length_shapes):
        n = tf.reduce_prod(shapes[i])
        idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
        count += n  
        part = part.write(i,i*tf.ones(n,tf.int32))
#         print(part.read(i)   ) 
        
    return idx,tensor_to_list(part)


def update_weights(OneD,part):
    params = tf.dynamic_partition(OneD, part, length_shapes)
    for i, (shape, param) in enumerate(zip(shapes, params)):
        z_hat.trainable_variables[i].assign(tf.reshape(param, shape))

def flatten_the_parameters(weights,idx):
    return tf.dynamic_stitch(idx, weights)

# %%
# @tf.function
def tensor_to_list(tensor):
    length_shapes = len(tf.shape_n(z_hat.trainable_variables))
    part_list = []
    for i in range(length_shapes):
        part_list.extend(part.read(i).numpy())
    return part_list 

@tf.function
def to_fix(z_hat):
    shapes = tf.shape_n(z_hat.trainable_variables)
    length_shapes = len(shapes)
    count = 0
    idx = []
    part = tf.TensorArray(tf.int32, size=0, dynamic_size=True, clear_after_read=False,infer_shape=False)
    # part = []

#     loss_pde,loss_ic = z_hat.loss(t)
#     total_loss = loss_pde + loss_ic

    for i in range(length_shapes):
        n = tf.reduce_prod(shapes[i])
        idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
        count += n  
        part = part.write(i,i*tf.ones(n,tf.int32))
#         print(part.read(i)   ) 
        
    return idx,tensor_to_list(part)


def update_weights(OneD,part):
    params = tf.dynamic_partition(OneD, part, length_shapes)
    for i, (shape, param) in enumerate(zip(shapes, params)):
        z_hat.trainable_variables[i].assign(tf.reshape(param, shape))

def flatten_the_parameters(weights,idx):
    return tf.dynamic_stitch(idx, weights)

# %%
optim = optim = tf.keras.optimizers.Adam()
lamda1 = 1.
alpha = 0.9
with tf.GradientTape() as tape:
    dresidue_pde,dresidue_ic   =  calc_imbalance(t)
    num = tf.reduce_max(tf.abs(flatten_the_parameters(dresidue_pde,idx)))
    den = tf.reduce_mean(tf.abs(flatten_the_parameters(dresidue_ic,idx)))
    lambda_hat = num/den

    lamda1 = (1. - alpha)*lamda1 + alpha*lambda_hat
    residue_pde, residue_ic = z_hat.loss(t)
    new_loss = residue_pde +lamda1*residue_ic
    print(new_loss)
dldparams = tape.gradient(new_loss, z_hat.trainable_variables)    
optim.apply_gradients(zip(dldparams, z_hat.trainable_variables))

residue_pde, residue_ic = z_hat.loss(t)
new_loss = residue_pde +lamda1*residue_ic
print(f'updated loss : {new_loss}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_32212/2053508906.py in <module>
#       3 alpha = 0.9
#       4 with tf.GradientTape() as tape:
# ----> 5     dresidue_pde,dresidue_ic   =  calc_imbalance(t)
#       6     num = tf.reduce_max(tf.abs(flatten_the_parameters(dresidue_pde,idx)))
#       7     den = tf.reduce_mean(tf.abs(flatten_the_parameters(dresidue_ic,idx)))
#
# ValueError: too many values to unpack (expected 2)

# %%
lambda_hat
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=19.717628>

# %%
z_hat.loss(t)
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=95.38633>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.0016374836>)

# %%
tfnum_per_layer
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=1.2112354>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.49196714>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=1.4633968>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.7859372>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.897468>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.7793293>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.96636623>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.0>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.32374984>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.75567853>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.5788212>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.4696628>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.6008834>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.37863946>]

# %%
tf.stack(num_per_layer)
# Out:
# <tf.Tensor: shape=(14,), dtype=float32, numpy=
# array([1.2112354 , 0.49196714, 1.4633968 , 0.7859372 , 0.897468  ,
#        0.7793293 , 0.96636623, 0.        , 0.32374984, 0.75567853,
#        0.5788212 , 0.4696628 , 0.6008834 , 0.37863946], dtype=float32)>

# %%
optim

# %%
@tf.function
def train_update_jun(t):
    S = len(tf.shape_n(z_hat.trainable_variables))
    lamda1 = 1.

    num_per_layer = []
    den_per_layer = []
    with tf.GradientTape() as tape:
        residue_pde, residue_ic,dresidue_pde,dresidue_ic   = calc_imbalance(t)
#         print(f'loss pde :{residue_pde} loss ic :{residue_ic}')
#         print(f'combined loss {residue_pde + residue_ic }')
        for i in range(S):
            lamda1 = 1.
            num = tf.reduce_max(tf.abs(dresidue_pde[i]))
            den = tf.reduce_mean(tf.abs(dresidue_ic[i]))

            if den == 0:
                print(f'den = {den}')
                den = 1e-10
                
            num_per_layer.append(num)
            den_per_layer.append(den)

        num_final =  tf.reduce_max( tf.stack(num_per_layer))    #stack flattens list
        den_final = tf.reduce_mean(tf.stack(den_per_layer))

        lambda_hat = num_final/den_final

        lamda1 = (1.-alpha)*lamda1 + alpha*lambda_hat

#         print(f'lambda for layer {i} is {lamda1}')
#         print(f'loss pde :{residue_pde} loss ic :{residue_ic}')
#         print(f'loss pde :{residue_pde} loss balcanced :{lamda1*residue_ic}')


        new_loss = residue_pde + lamda1*residue_ic
#         print(f'final loss before :{new_loss}')
    dddd = tape.gradient(new_loss, z_hat.trainable_variables)    
    optim.apply_gradients(zip(dddd, z_hat.trainable_variables))
    return new_loss

# %%
start = time.time()
losses = []
loss_decrease = []
best_so_far = np.inf
losses.append(train_update_jun(t))

for epoch in range(50000):
    loss = train_update_jun(t)
    if loss < losses[-1]:
        if loss < best_so_far:
            best_so_far = loss
            loss_decrease.append(loss)
#                 print(f'******************best so far is updated to :{best_so_far}********************')
            z_hat.save_weights('best_model')
             

    if np.isnan(loss):
        print(f'Loss :{loss}')
        break

    losses.append(loss)

    if epoch%1000==0:
        print(f'loss for epoch {epoch} : {loss} best so far {best_so_far}') 
        print(end = ".")

z_hat.load_weights('best_model')
# Out:
# loss for epoch 0 : 1.892171349027194e-05 best so far 1.892171349027194e-05
# .loss for epoch 1000 : 2.7969610528089106e-05 best so far 1.8536766219767742e-05
# .loss for epoch 2000 : 0.006440671160817146 best so far 1.8536766219767742e-05
# .loss for epoch 3000 : 2.3784974473528564e-05 best so far 1.8536766219767742e-05
# .loss for epoch 4000 : 0.007400022819638252 best so far 1.8536766219767742e-05
# .loss for epoch 5000 : 2.188183498219587e-05 best so far 1.8536766219767742e-05
# .loss for epoch 6000 : 2.9181606805650517e-05 best so far 1.8536766219767742e-05
# .loss for epoch 7000 : 2.4682532966835424e-05 best so far 1.8536766219767742e-05
# .loss for epoch 8000 : 3.1292565836338326e-05 best so far 1.8536766219767742e-05
# .loss for epoch 9000 : 2.871823926398065e-05 best so far 1.8536766219767742e-05
# .loss for epoch 10000 : 7.686689787078649e-05 best so far 1.8536766219767742e-05
# .loss for epoch 11000 : 2.755907735263463e-05 best so far 1.8536766219767742e-05
# .loss for epoch 12000 : 7.756249397061765e-05 best so far 1.8536766219767742e-05
# .loss for epoch 13000 : 3.47132227034308e-05 best so far 1.8536766219767742e-05
# .loss for epoch 14000 : 2.55942068179138e-05 best so far 1.8536766219767742e-05
# .loss for epoch 15000 : 3.216825280105695e-05 best so far 1.8536766219767742e-05
# .loss for epoch 16000 : 2.8456201107474044e-05 best so far 1.8536766219767742e-05
# .loss for epoch 17000 : 3.481940075289458e-05 best so far 1.8536766219767742e-05
# .loss for epoch 18000 : 2.869361014745664e-05 best so far 1.8536766219767742e-05
# .loss for epoch 19000 : 2.470374784024898e-05 best so far 1.8536766219767742e-05
# .loss for epoch 20000 : 0.06297386437654495 best so far 1.8536766219767742e-05
# .loss for epoch 21000 : 2.7082800443167798e-05 best so far 1.8536766219767742e-05
# .loss for epoch 22000 : 2.3163927835412323e-05 best so far 1.8536766219767742e-05
# .loss for epoch 23000 : 2.20316960621858e-05 best so far 1.8536766219767742e-05
# .loss for epoch 24000 : 2.482758463884238e-05 best so far 1.8536766219767742e-05
# .loss for epoch 25000 : 2.0734212739625946e-05 best so far 1.8536766219767742e-05
# .loss for epoch 26000 : 0.0003717373765539378 best so far 1.8536766219767742e-05
# .loss for epoch 27000 : 2.0858069547102787e-05 best so far 1.8536766219767742e-05
# .loss for epoch 28000 : 1.6614862033748068e-05 best so far 1.6614862033748068e-05
# .loss for epoch 29000 : 0.0001282424491364509 best so far 1.5196253116300795e-05
# .loss for epoch 30000 : 0.11753340065479279 best so far 1.3711336578126065e-05
# .loss for epoch 31000 : 1.5059146790008526e-05 best so far 1.3711336578126065e-05
# .loss for epoch 32000 : 0.01676488295197487 best so far 1.28873380162986e-05
# .loss for epoch 33000 : 1.2622732356248889e-05 best so far 1.2622732356248889e-05
# .loss for epoch 34000 : 0.0004570138989947736 best so far 1.2091147254977841e-05
# .loss for epoch 35000 : 1.4707956324855331e-05 best so far 1.1704983990057372e-05
# .loss for epoch 36000 : 1.2486204468586948e-05 best so far 1.1704983990057372e-05
# .loss for epoch 37000 : 0.0015511304372921586 best so far 1.1501682820380665e-05
# .loss for epoch 38000 : 0.04195254296064377 best so far 1.0788297913677525e-05
# .loss for epoch 39000 : 1.0786324310174678e-05 best so far 1.0642317647580057e-05
# .loss for epoch 40000 : 1.0729382665886078e-05 best so far 1.0588628356344998e-05
# .loss for epoch 41000 : 6.414564268197864e-05 best so far 1.0272759027429856e-05
# .loss for epoch 42000 : 0.00015731982421129942 best so far 9.72963243839331e-06
# .loss for epoch 43000 : 1.4046959222469013e-05 best so far 9.406585377291776e-06
# .loss for epoch 44000 : 1.2377643543004524e-05 best so far 9.406585377291776e-06
# .loss for epoch 45000 : 2.5914672733051702e-05 best so far 9.406585377291776e-06
# .loss for epoch 46000 : 0.0004941904917359352 best so far 9.406585377291776e-06
# .loss for epoch 47000 : 0.0005135161918587983 best so far 9.406585377291776e-06
# .loss for epoch 48000 : 0.0013261066051200032 best so far 9.406585377291776e-06
# .loss for epoch 49000 : 1.0465104423929006e-05 best so far 9.406585377291776e-06
# .

# %%
tf.norm(loss_decrease[-1],2)< 1e-6
# Out:
# <tf.Tensor: shape=(), dtype=bool, numpy=False>

# %%
1e-6, 10**(-6)
# Out:
# (1e-06, 1e-06)

# %%
mix_optimizers()
# Out:
# Initial loss : 4.06309209211031e-06
# converged: False
# num_iterations 63 and evaluations 258
# gradient:0.0012986954534426332
#
# NO change
# Initial loss : 3.889121217071079e-06
# converged: False
# num_iterations 7 and evaluations 75
# gradient:0.0011274470016360283
#
# NO change
# Initial loss : 3.816031494352501e-06
# converged: False
# num_iterations 2 and evaluations 47
# gradient:0.00027217165916226804
#
# NO change
# Initial loss : 3.816156549873995e-06
# converged: False
# num_iterations 17 and evaluations 127
# gradient:0.0003543308994267136
#
# NO change
# Initial loss : 3.7913298456260236e-06
# converged: False
# num_iterations 14 and evaluations 87
# gradient:0.00047321911551989615
#
# NO change
# Initial loss : 3.7759148199256742e-06
# converged: True
# num_iterations 2 and evaluations 37
# gradient:0.000697823241353035
# loss tf.Tensor(3.7752661e-06, shape=(), dtype=float32)
# Times :  0.5408127307891846
#
# converged: False
# num_iterations 14 and evaluations 87
# gradient:0.00047321911551989615
#
# NO change
# Initial loss : 3.7757297377538634e-06
# converged: False
# num_iterations 10 and evaluations 86
# gradient:0.0013669857289642096
#
# NO change
# Initial loss : 3.767993121073232e-06
# converged: False
# num_iterations 1 and evaluations 35
# gradient:0.001524660037830472
#
# NO change
# Initial loss : 3.771249112105579e-06
# converged: False
# num_iterations 7 and evaluations 68
# gradient:0.0005337665788829327
#
# NO change
# Initial loss : 3.7680545119656017e-06
# converged: False
# num_iterations 5 and evaluations 98
# gradient:0.00046080854372121394
#
# NO change
# Initial loss : 3.767238467844436e-06
# converged: True
# num_iterations 7 and evaluations 96
# gradient:0.0004551453166641295
# loss tf.Tensor(3.7649254e-06, shape=(), dtype=float32)
# Times :  1.393721103668213
#
# converged: False
# num_iterations 5 and evaluations 98
# gradient:0.00046080854372121394
#
# NO change
# Initial loss : 3.7670320125471335e-06
# converged: False
# num_iterations 4 and evaluations 37
# gradient:0.0002751397551037371
#
# NO change
# Initial loss : 3.7658762721548555e-06
# converged: False
# num_iterations 3 and evaluations 41
# gradient:0.00044835740118287504
#
# NO change
# Initial loss : 3.766432655538665e-06
# converged: True
# num_iterations 4 and evaluations 73
# gradient:0.0002751101856119931
# loss tf.Tensor(3.7654465e-06, shape=(), dtype=float32)
# Times :  1.0573844909667969
#
# converged: False
# num_iterations 3 and evaluations 41
# gradient:0.00044835740118287504
#
# NO change
# Initial loss : 3.766626605283818e-06
# converged: False
# num_iterations 3 and evaluations 60
# gradient:0.0002787977864500135
#
# NO change
# Initial loss : 3.7657259781553876e-06
# converged: False
# num_iterations 3 and evaluations 65
# gradient:0.00045104281161911786
#
# NO change
# Initial loss : 3.766147301575984e-06
# converged: False
# num_iterations 1 and evaluations 35
# gradient:0.0004496665205806494
#
# NO change
# Initial loss : 3.766161626117537e-06
# converged: False
# num_iterations 3 and evaluations 34
# gradient:0.0004520229122135788
#
# NO change
# Initial loss : 3.7669688026653603e-06
# converged: False
# num_iterations 2 and evaluations 30
# gradient:0.00027634628349915147
#
# NO change
# Initial loss : 3.7971906294842483e-06
# converged: False
# num_iterations 4 and evaluations 43
# gradient:0.0004513029707595706
#
# NO change
# Initial loss : 3.803907020483166e-06
# converged: False
# num_iterations 4 and evaluations 69
# gradient:0.00045754684833809733
#
# NO change
# Initial loss : 3.7669226458092453e-06
# converged: False
# num_iterations 2 and evaluations 34
# gradient:0.00045209116069599986
#
# NO change
# Initial loss : 3.7690583667426836e-06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_32212/3720265982.py in <module>
# ----> 1 mix_optimizers()
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      63                 break
#      64             else:
# ---> 65                 mix_optimizers()
#      66                 if optim_results.converged.numpy() == True:
#      67                     break
#
# /tmp/ipykernel_32212/2860435247.py in mix_optimizers()
#      42     start = tf.constant(flat_parameters)  # Starting point for the search.
#      43     grads_lists = []
# ---> 44     optim_results = tfp.optimizer.lbfgs_minimize(
#      45       value_and_gradient, initial_position=start, tolerance=1.0e-20, max_iterations=5000)
#      46     grad_curr = tf.norm(optim_results.objective_gradient,ord=np.inf)
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/lbfgs.py in minimize(value_and_gradients_function, initial_position, previous_optimizer_results, num_correction_pairs, tolerance, x_tolerance, f_relative_tolerance, initial_inverse_hessian_estimate, max_iterations, parallel_iterations, stopping_condition, max_line_search_iterations, f_absolute_tolerance, name)
#     283       initial_state = previous_optimizer_results
#     284
# --> 285     return tf.while_loop(
#     286         cond=_cond,
#     287         body=_body,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     627                   func.__module__, arg_name, arg_value, 'in a future version'
#     628                   if date is None else ('after %s' % date), instructions)
# --> 629       return func(*args, **kwargs)
#     630
#     631     doc = _add_deprecated_arg_value_notice_to_docstring(
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2511
#    2512   """
# -> 2513   return while_loop(
#    2514       cond=cond,
#    2515       body=body,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2760                                               list(loop_vars))
#    2761       while cond(*loop_vars):
# -> 2762         loop_vars = body(*loop_vars)
#    2763         if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2764           packed = True
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/lbfgs.py in _body(current_state)
#     257       # search direction.
#     258
# --> 259       next_state = bfgs_utils.line_search_step(
#     260           current_state, value_and_gradients_function, search_direction,
#     261           tolerance, f_relative_tolerance, x_tolerance, stopping_condition,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/bfgs_utils.py in line_search_step(state, value_and_gradients_function, search_direction, grad_tolerance, f_relative_tolerance, x_tolerance, stopping_condition, max_iterations, f_absolute_tolerance)
#     207                            full_gradient=state.objective_gradient)
#     208   inactive = state.failed | state.converged
# --> 209   ls_result = hager_zhang(
#     210       line_search_value_grad_func,
#     211       initial_step_size=_broadcast(1, state.position),
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in hager_zhang(value_and_gradients_function, initial_step_size, value_at_initial_step, value_at_zero, converged, threshold_use_approximate_wolfe_condition, shrinkage_param, expansion_param, sufficient_decrease_param, curvature_param, max_iterations, name)
#     272
#     273     init_active = ~init_interval.failed & ~init_interval.converged
# --> 274     return prefer_static.cond(
#     275         tf.reduce_any(init_active),
#     276         _apply_bracket_and_search,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/internal/prefer_static.py in cond(pred, true_fn, false_fn, name)
#     254   if pred_value is not None:
#     255     if pred_value:
# --> 256       return true_fn()
#     257     else:
#     258       return false_fn()
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in _apply_bracket_and_search()
#     266     def _apply_bracket_and_search():
#     267       """Bracketing and searching to do for valid inputs."""
# --> 268       return _bracket_and_search(
#     269           value_and_gradients_function, init_interval, f_lim, max_iterations,
#     270           shrinkage_param, expansion_param, sufficient_decrease_param,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in _bracket_and_search(value_and_gradients_function, init_interval, f_lim, max_iterations, shrinkage_param, expansion_param, sufficient_decrease_param, curvature_param)
#     369       right=bracket_result.right)
#     370
# --> 371   return _line_search_after_bracketing(
#     372       value_and_gradients_function, line_search_args, init_interval.left,
#     373       f_lim, max_iterations, sufficient_decrease_param, curvature_param,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in _line_search_after_bracketing(value_and_gradients_function, search_interval, val_0, f_lim, max_iterations, sufficient_decrease_param, curvature_param, shrinkage_param)
#     496     return [next_args._replace(converged=next_args.converged | interval_shrunk)]
#     497
# --> 498   return tf.while_loop(
#     499       cond=_loop_cond,
#     500       body=_loop_body,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     627                   func.__module__, arg_name, arg_value, 'in a future version'
#     628                   if date is None else ('after %s' % date), instructions)
# --> 629       return func(*args, **kwargs)
#     630
#     631     doc = _add_deprecated_arg_value_notice_to_docstring(
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2511
#    2512   """
# -> 2513   return while_loop(
#    2514       cond=cond,
#    2515       body=body,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2760                                               list(loop_vars))
#    2761       while cond(*loop_vars):
# -> 2762         loop_vars = body(*loop_vars)
#    2763         if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2764           packed = True
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in _loop_body(curr_interval)
#     446     active = ~(curr_interval.converged | curr_interval.failed)
#     447     # TODO(b/208441613): Skip updates for batch members that are not active?
# --> 448     secant2_raw_result = hzl.secant2(
#     449         value_and_gradients_function, val_0, curr_interval, f_lim,
#     450         sufficient_decrease_param, curvature_param)
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/internal/hager_zhang_lib.py in secant2(value_and_gradients_function, val_0, search_interval, f_lim, sufficient_decrease_param, curvature_param, name)
#     167           curvature_param)
#     168
# --> 169     return prefer_static.cond(
#     170         tf.reduce_any(initial_args.active),
#     171         _apply_secant2_inner,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/internal/prefer_static.py in cond(pred, true_fn, false_fn, name)
#     254   if pred_value is not None:
#     255     if pred_value:
# --> 256       return true_fn()
#     257     else:
#     258       return false_fn()
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/internal/hager_zhang_lib.py in _apply_secant2_inner()
#     158
#     159     def _apply_secant2_inner():
# --> 160       return _secant2_inner(
#     161           value_and_gradients_function,
#     162           initial_args,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/internal/hager_zhang_lib.py in _secant2_inner(value_and_gradients_function, initial_args, val_0, val_c, f_lim, sufficient_decrease_param, curvature_param)
#     183   # Apply the `update` function on active branch members to squeeze their
#     184   # bracketing interval.
# --> 185   update_result = update(value_and_gradients_function,
#     186                          initial_args.left,
#     187                          initial_args.right,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/internal/hager_zhang_lib.py in update(value_and_gradients_function, val_left, val_right, val_trial, f_lim, active)
#     408   # with the trial point.
#     409   left = val_where(within_range & valid_left, val_trial, val_left)
# --> 410   right = val_where(within_range & ~valid_left, val_trial, val_right)
#     411
#     412   bisect_args = _IntermediateResult(
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#    1405         #   r_binary_op_wrapper use different force_same_dtype values.
#    1406         x, y = maybe_promote_tensors(x, y)
# -> 1407         return func(x, y, name=name)
#    1408       except (TypeError, ValueError) as e:
#    1409         # Even if dispatching the op failed, the RHS may be a tensor aware
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py in and_(x, y, name)
#    1842 def and_(x, y, name=None):
#    1843   if x.dtype == dtypes.bool:
# -> 1844     return gen_math_ops.logical_and(x, y, name)
#    1845   return gen_bitwise_ops.bitwise_and(x, y)
#    1846
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/gen_math_ops.py in logical_and(x, y, name)
#    5692   if tld.is_eager:
#    5693     try:
# -> 5694       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    5695         _ctx, "LogicalAnd", name, x, y)
#    5696       return _result
#
# KeyboardInterrupt:

# %%
true_v = lambda t: g*t + v0
plt.plot(t,true_v(t),'o')
plt.plot(t, z_hat(t))
plt.legend(['True','NN'])

# %%
def mix_optimizers():
    shapes = tf.shape_n(z_hat.trainable_variables)
    length_shapes = len(shapes)
    count = 0
    idx = []
    part = []

    loss_pde,loss_ic = z_hat.loss(t)
    total_loss = train_update_jun(t)
    print(f'Initial loss : {total_loss}')


    for i in range(length_shapes):
        n = np.product(shapes[i])
        idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
        count += n   
        part.extend([i]*n)

    def update_weights(OneD):
        params = tf.dynamic_partition(OneD, part, length_shapes)
        for i, (shape, param) in enumerate(zip(shapes, params)):
            z_hat.trainable_variables[i].assign(tf.reshape(param, shape))

    def flatten_the_parameters(weights):
        return tf.dynamic_stitch(idx, weights) 

#     @tf.function
    def value_and_gradient(flat_weights):
        #update weights 
        update_weights(flat_weights)
        with tf.GradientTape() as g:
            loss_pde,loss_ic = z_hat.loss(t)
            los = train_update_jun(t)
        grad = g.gradient(los, z_hat.trainable_variables) 
        flattend_grad = flatten_the_parameters(grad) #converts from multDim to 1D
        return los, flattend_grad  


    start_time2 = time.time()

    flat_parameters = flatten_the_parameters(z_hat.trainable_variables)
    start = tf.constant(flat_parameters)  # Starting point for the search.
    grads_lists = []
    optim_results = tfp.optimizer.lbfgs_minimize(
      value_and_gradient, initial_position=start, tolerance=1.0e-20, max_iterations=5000)
    grad_curr = tf.norm(optim_results.objective_gradient,ord=np.inf)
    grads_lists.append(grad_curr)
    
    if optim_results.converged.numpy() == True:
        break

    while  optim_results.converged.numpy() == False:
        optim_results = tfp.optimizer.lbfgs_minimize(
      value_and_gradient, initial_position=start, max_iterations=5000)
        print('converged:', optim_results.converged.numpy())
        print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
        print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
        print('')
        new_grad = tf.norm(optim_results.objective_gradient,ord=np.inf)

        if new_grad == grads_lists[-1]:
            print('NO change')
            loss = train_update_jun(t)
            if loss < 1e-6:
                print('satiesfied')
                break
            else:
                mix_optimizers()
                



    print('converged:', optim_results.converged.numpy())
    print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
    print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
    update_weights(optim_results.position)

    loss_pde,loss_ic = z_hat.loss(t)
    los = loss_pde + loss_ic
    print('loss',los)
    print('Times : ',time.time()-start_time2,'\n')

# %%
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.6820945>

# %%
S = length_shapes
lamda1 = 1.

num_per_layer = []
den_per_layer = []
with tf.GradientTape() as tape:
    residue_pde, residue_ic,dresidue_pde,dresidue_ic   = calc_imbalance(t)
    print(f'loss pde :{residue_pde} loss ic :{residue_ic}')
    print(f'combined loss {residue_pde + residue_ic }')
    for i in range(S):
        lamda1 = 1.
        num = tf.reduce_max(tf.abs(tf.reshape(dresidue_pde[i],(-1))))
        den = tf.reduce_mean(tf.abs(tf.reshape(dresidue_ic[i],(-1))))

        num_per_layer.append(num)
        den_per_layer.append(den)

    num_final =  tf.reduce_max( tf.stack(num_per_layer))    #stack flattens list
    den_final = tf.reduce_mean(tf.stack(den_per_layer))

    lambda_hat = num_final/den_final

    lamda1 = (1.-alpha)*lamda1 + alpha*lambda_hat

    print(f'lambda for layer {i} is {lamda1}')
    print(f'loss pde :{residue_pde} loss ic :{residue_ic}')
    print(f'loss pde :{residue_pde} loss balcanced :{lamda1*residue_ic}')
    

    new_loss = residue_pde + lamda1*residue_ic
    print(f'final loss before :{new_loss}')
dddd = tape.gradient(new_loss, z_hat.trainable_variables)    
optim.apply_gradients(zip(dddd, z_hat.trainable_variables))

residue_pde, residue_ic,dresidue_pde,dresidue_ic   = calc_imbalance(t)
new_loss = residue_pde + lamda1*residue_ic
new_loss = residue_pde + lamda1*residue_ic
print(f'final loss after update :{new_loss}')
#     plt.title('Gradients for parameter '+str(i))
#     plt.plot(tf.reshape(dresidue_pde[i],(-1)), label ='pde_res'+str(i) )
#     plt.plot(tf.reshape(dresidue_ic[i],(-1)),label ='ics_res'+str(i))
#     plt.legend()
#     plt.show()
    
#     plt.title('modified Gradients for parameter '+str(i))
#     plt.plot(tf.reshape(dresidue_pde[i],(-1)), label ='mod_pde_res'+str(i) )
#     plt.plot(tf.reshape(lamda1*dresidue_ic[i],(-1)),label ='mod_ics_res'+str(i))
#     plt.legend()
#     plt.show()
    
    
    
    
    
    
#             if tf.size(grad_residual_x[n].shape) == 2 and grad_residual_x[n].shape[0] == 1:
#                 plt.plot(grad_residual_x[n][0],label = 'grad_res')
#                 plt.plot(grad_mse_x0_real[n][0],label = 'grad_IC')
#                 plt.title('layer_corrected = '+str(n))
#                 plt.legend()
#                 plt.show()


#             print(f'shapes:{grad_residual_x[n].shape} \n reduce_prod :{tf.reduce_prod(grad_residual_x[n].shape)}')
#     max_grad_res_list_real.append( tf.reduce_max(tf.math.abs(grad_residual_x[n])))
#     max_grad_res_list_imag.append( tf.reduce_max(tf.math.abs(grad_residual_y[n])))

#     max_grad_res_list_real_bc.append( tf.reduce_mean(tf.math.abs(grad_mse_x0_real[n])))
#     max_grad_res_list_imag_bc.append( tf.reduce_mean(tf.math.abs(grad_mse_y0_imag[n])) )

# lambda_residue_hat_real = tf.reduce_max(max_grad_res_list_real) / tf.reduce_mean(max_grad_res_list_real_bc)
# lambda_residue_hat_imag = tf.reduce_max(max_grad_res_list_imag) / tf.reduce_mean(max_grad_res_list_imag_bc)

# lambda_real = (1. - alpha)*lambda_real + alpha*lambda_residue_hat_real
# lambda_imag = (1. - alpha)*lambda_imag + alpha*lambda_residue_hat_imag 

# total_loss_updated = residual_x + mse_x0_real*lambda_real  + residual_y + mse_y0_imag*lambda_imag
# #         print(f'loss residue_real :{residual_x} ,loss residue_imag :{residual_y}' )
# #         print('Old loss_bc')
# #         print(f'loss residue_real_bc :{mse_x0_real} ,loss residue_imag_bc :{mse_y0_imag}' )
# #         print('New loss_bc')
# #         print(f'loss residue_real_bc :{mse_x0_real*lambda_real} ,loss residue_imag_bc :{mse_y0_imag*lambda_imag}' )        
# #         print(f'New lambda_real :{lambda_real}...New lambda_imag :{lambda_imag} ')
# return total_loss_updated
# Out:
# loss pde :93.70259857177734 loss ic :0.0017828199779614806
# combined loss 93.70438385009766
# lambda for layer 13 is 129.48974609375
# loss pde :93.70259857177734 loss ic :0.0017828199779614806
# loss pde :93.70259857177734 loss balcanced :0.23085691034793854
# final loss before :93.93345642089844
# final loss after update :93.66506958007812

# %%
tf.reduce_max(tf.abs(flatten_the_parameters(dresidue_ic,idx)))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.06863141>

# %%
def balance_loss(t) :


    @tf.function
    def to_fix(z_hat):
        shapes = tf.shape_n(z_hat.trainable_variables)
        length_shapes = len(shapes)
        count = 0
        idx = []
        part = tf.TensorArray(tf.int32, size=0, dynamic_size=True, clear_after_read=False,infer_shape=False)
        # part = []

    #     loss_pde,loss_ic = z_hat.loss(t)
    #     total_loss = loss_pde + loss_ic

        for i in range(length_shapes):
            n = tf.reduce_prod(shapes[i])
            idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
            count += n  
            part = part.write(i,i*tf.ones(n,tf.int32))
    #         print(part.read(i)   )
    
        def tensor_to_list(tensor):
            length_shapes = len(tf.shape_n(z_hat.trainable_variables))
            part_list = []
            for i in range(length_shapes):
                part_list.extend(part.read(i).numpy())
            return part_list 
        
        return idx,tensor_to_list(part)


    def update_weights(OneD,part):
        params = tf.dynamic_partition(OneD, part, length_shapes)
        for i, (shape, param) in enumerate(zip(shapes, params)):
            z_hat.trainable_variables[i].assign(tf.reshape(param, shape))

    def flatten_the_parameters(weights,idx):
        return tf.dynamic_stitch(idx, weights) 

    weights = z_hat.trainable_variables
    idx, part = to_fix(z_hat)
    
    dresidue_pde,dresidue_ic   =  calc_imbalance(t)
    num = tf.reduce_max(tf.abs(flatten_the_parameters(dresidue_pde,idx)))
    den = tf.reduce_mean(tf.abs(flatten_the_parameters(dresidue_ic,idx)))
    lambda_hat = num/den
    residue_pde, residue_ic = z_hat.loss(t)
    return residue_pde +lamda1*residue_ic

# %%
weights = z_hat.trainable_variables
idx, part = to_fix(z_hat)

# %%
dresidue_pde,dresidue_ic   =  calc_imbalance(t)

# %%
balance_loss(t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_29937/2671118193.py in <module>
# ----> 1 balance_loss(t)
#
# /tmp/ipykernel_29937/1452474124.py in balance_loss(t)
#      45
#      46     weights = z_hat.trainable_variables
# ---> 47     idx, part = to_fix(z_hat)
#      48
#      49     dresidue_pde,dresidue_ic   =  calc_imbalance(t)
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /tmp/__autograph_generated_file75_zevnp.py in tf__to_fix(z_hat)
#      61                 try:
#      62                     do_return = True
# ---> 63                     retval_ = (ag__.ld(idx), ag__.converted_call(ag__.ld(tensor_to_list), (ag__.ld(part),), None, fscope))
#      64                 except:
#      65                     do_return = False
#
# /tmp/__autograph_generated_file75_zevnp.py in tensor_to_list(tensor)
#      51                             ag__.converted_call(ag__.ld(part_list).extend, (ag__.converted_call(ag__.converted_call(ag__.ld(part).read, (ag__.ld(i),), None, fscope_1).numpy, (), None, fscope_1),), None, fscope_1)
#      52                         i = ag__.Undefined('i')
# ---> 53                         ag__.for_stmt(ag__.converted_call(ag__.ld(range), (ag__.ld(length_shapes),), None, fscope_1), None, loop_body_1, get_state_1, set_state_1, (), {'iterate_names': 'i'})
#      54                         try:
#      55                             do_return_1 = True
#
# /tmp/__autograph_generated_file75_zevnp.py in loop_body_1(itr_1)
#      49                         def loop_body_1(itr_1):
#      50                             i = itr_1
# ---> 51                             ag__.converted_call(ag__.ld(part_list).extend, (ag__.converted_call(ag__.converted_call(ag__.ld(part).read, (ag__.ld(i),), None, fscope_1).numpy, (), None, fscope_1),), None, fscope_1)
#      52                         i = ag__.Undefined('i')
#      53                         ag__.for_stmt(ag__.converted_call(ag__.ld(range), (ag__.ld(length_shapes),), None, fscope_1), None, loop_body_1, get_state_1, set_state_1, (), {'iterate_names': 'i'})
#
# AttributeError: in user code:
#
#     File "/tmp/ipykernel_29937/1452474124.py", line 32, in tensor_to_list  *
#         part_list.extend(part.read(i).numpy())
#
#     AttributeError: 'Tensor' object has no attribute 'numpy'

# %%
def train_and_update_with_balanced_loss(t):
    with tf.GradientTape() as tape:
        bloss = balance_loss(t)
    dbloss_up = tape.gradient(bloss,z_hat.trainable_variables)  
    optim.apply_gradients(zip(dbloss_up, z_hat.trainable_variables))
    return bloss

# %%
epochs = 10000
losses =[]
loss_decrease = []
check_decrease = 0
initial_loss = train_and_update_with_balanced_loss(t).numpy()
print(f'Initial loss :{initial_loss}')
best_so_far =  np.inf
losses.append(initial_loss)
for epoch in tnrange(epochs):
    loss = train_and_update_with_balanced_loss(t).numpy()
    if loss < losses[-1]:
        if loss < best_so_far:
            best_so_far = loss
            loss_decrease.append(loss)
#                 print(f'******************best so far is updated to :{best_so_far}********************')
            z_hat.save_weights('best_model')
            check_decrease = loss  
    losses.append(loss)

    if epoch%1000==0:
        print(f'loss for epoch {epoch} : {loss} best so far {best_so_far}') 
        print(end = ".")
# Out:
# Initial loss :96.01844024658203
#   0%|          | 0/10000 [00:00<?, ?it/s]
# loss for epoch 0 : 96.01856994628906 best so far inf
# .loss for epoch 1000 : 96.01744079589844 best so far 96.01699829101562
# .loss for epoch 2000 : 185.3406982421875 best so far 96.01007843017578
# .loss for epoch 3000 : 96.0087661743164 best so far 95.98133850097656
# .loss for epoch 4000 : 1980.7257080078125 best so far 95.98133850097656
# .loss for epoch 5000 : 200.23910522460938 best so far 95.98133850097656
# .loss for epoch 6000 : 114.69535827636719 best so far 95.98133850097656
# .loss for epoch 7000 : 95.98522186279297 best so far 95.98133850097656
# .loss for epoch 8000 : 95.98443603515625 best so far 95.98133850097656
# .loss for epoch 9000 : 95.98332977294922 best so far 95.98133850097656
# .

# %%
def mix_optimizers():
    shapes = tf.shape_n(z_hat.trainable_variables)
    length_shapes = len(shapes)
    count = 0
    idx = []
    part = []

    loss_pde,loss_ic = z_hat.loss(t)
    total_loss = train_and_update_with_balanced_loss(t)
    print(f'Initial loss : {total_loss}')


    for i in range(length_shapes):
        n = np.product(shapes[i])
        idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
        count += n   
        part.extend([i]*n)

    def update_weights(OneD):
        params = tf.dynamic_partition(OneD, part, length_shapes)
        for i, (shape, param) in enumerate(zip(shapes, params)):
            z_hat.trainable_variables[i].assign(tf.reshape(param, shape))

    def flatten_the_parameters(weights):
        return tf.dynamic_stitch(idx, weights) 

#     @tf.function
    def value_and_gradient(flat_weights):
        #update weights 
        update_weights(flat_weights)
        with tf.GradientTape() as g:
            loss_pde,loss_ic = z_hat.loss(t)
            los = train_and_update_with_balanced_loss(t)
        grad = g.gradient(los, z_hat.trainable_variables) 
        flattend_grad = flatten_the_parameters(grad) #converts from multDim to 1D
        return los, flattend_grad  


    start_time2 = time.time()

    flat_parameters = flatten_the_parameters(z_hat.trainable_variables)
    start = tf.constant(flat_parameters)  # Starting point for the search.
    grads_lists = []
    optim_results = tfp.optimizer.lbfgs_minimize(
      value_and_gradient, initial_position=start, tolerance=1.0e-20, max_iterations=5000)
    grad_curr = tf.norm(optim_results.objective_gradient,ord=np.inf)
    grads_lists.append(grad_curr)

    while  optim_results.converged.numpy() == False:
        optim_results = tfp.optimizer.lbfgs_minimize(
      value_and_gradient, initial_position=start, max_iterations=5000)
        print('converged:', optim_results.converged.numpy())
        print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
        print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
        print('')
        new_grad = tf.norm(optim_results.objective_gradient,ord=np.inf)

        if new_grad == grads_lists[-1]:
            print('NO change')
#             train_update_step(t,10000,True)
#             mix_optimizers()
            break



    print('converged:', optim_results.converged.numpy())
    print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
    print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
    update_weights(optim_results.position)

    loss_pde,loss_ic = z_hat.loss(t)
    los = loss_pde + loss_ic
    print('loss',los)
    print('Times : ',time.time()-start_time2,'\n')

# %%
mix_optimizers()
# Out:
# Initial loss : 95.98187255859375
# converged: True
# num_iterations 3 and evaluations 8
# gradient:59.69276809692383
# loss tf.Tensor(95.98169, shape=(), dtype=float32)
# Times :  0.8856480121612549

# %%
    for epoch in tnrange(epochs):
        loss = train_and_update(t).numpy()

        if loss < losses[-1]:
            if loss < best_so_far:
                best_so_far = loss
                loss_decrease.append(loss)
#                 print(f'******************best so far is updated to :{best_so_far}********************')
                z_hat.save_weights('best_model')
                check_decrease = loss  

        if np.isnan(loss):
            print(f'Loss :{loss}')
            break

        losses.append(loss)

        if epoch%1000==0:
            print(f'loss for epoch {epoch} : {loss} best so far {best_so_far}') 
            print(end = ".")

    z_hat.load_weights('best_model')
    
    mix_optimizers()

# %%
plt.plot(lo)

# %%
lo[-1]
# Out:
# 95.10872

# %%
train_and_update_with_balanced_loss(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=301449800.0>

# %%
dresidue_pde,dresidue_ic = calc_imbalance(t)
lamda1 = 1.
alpha = 0.9

for i in range(len(tf.shape_n(z_hat.trainable_variables))):
    num = tf.reduce_max(tf.abs(tf.reshape(dresidue_pde[i],(-1))))
    den = tf.reduce_mean(tf.abs(tf.reshape(dresidue_ic[i],(-1))))+1e-10
    
    lambda_hat = num/den
    
    lamda1 = (1.-alpha)*lamda1 + alpha*lambda_hat
        
    print(f'lambda hat for layer {i} is {lamda1}')
    print(f'dres ic {tf.reshape(dresidue_ic[i],(-1))[0]}')
#     print(tf.reshape(dresidue_pde[i],(-1)), tf.reshape(lamda1*dresidue_ic[i],(-1)))
    
    
    plt.title('Gradients for parameter '+str(i))
    plt.plot(tf.reshape(dresidue_pde[i],(-1)), label ='pde_res'+str(i) )
    plt.plot(tf.reshape(dresidue_ic[i],(-1)),label ='ics_res'+str(i))
    plt.legend()
    plt.show()
    
    plt.title('modified Gradients for parameter '+str(i))
    plt.plot(tf.reshape(dresidue_pde[i],(-1)), label ='mod_pde_res'+str(i) )
    plt.plot(tf.reshape(lamda1*dresidue_ic[i],(-1)),label ='mod_ics_res'+str(i))
    plt.legend()
    plt.show()
# Out:
# lambda hat for layer 0 is 113469825024.0
# dres ic 0.0
# lambda hat for layer 1 is 19053199360.0
# dres ic 1.1448746811693056e-10
# lambda hat for layer 2 is 71231946752.0
# dres ic 0.0
# lambda hat for layer 3 is 12631983104.0
# dres ic 4.03260792813942e-11
# lambda hat for layer 4 is 32668487680.0
# dres ic 0.0
# lambda hat for layer 5 is 5932869120.0
# dres ic -3.459042774434096e-11
# lambda hat for layer 6 is 45951246336.0
# dres ic 0.0
# lambda hat for layer 7 is 4595124736.0
# dres ic -2.000000026702864e-10
# lambda hat for layer 8 is 11977453568.0
# dres ic 0.0
# lambda hat for layer 9 is 7147777024.0
# dres ic 5.831186228322238e-12
# lambda hat for layer 10 is 28919451648.0
# dres ic 0.0
# lambda hat for layer 11 is 7310302208.0
# dres ic 1.1454470011384998e-10
# lambda hat for layer 12 is 21747904512.0
# dres ic 0.0
# lambda hat for layer 13 is 4790254592.0
# dres ic 4.0346240237632e-11

# %%
optim = tf.keras.optimizers.Adam()

@tf.function
def train_and_update(t):
    with tf.GradientTape() as tape:
        loss_pde,loss_ic = z_hat.loss(t)
        total_loss = loss_pde + loss_ic
    dlossdpa = tape.gradient(total_loss, z_hat.trainable_variables) 
    optim.apply_gradients(zip(dlossdpa, z_hat.trainable_variables))
    return total_loss

def calc_imbalance(t):
    with tf.GradientTape(persistent=True) as tape:
        residue_pde, residue_ic = z_hat.loss(t)
    dresidue_pde = tape.gradient(residue_pde,z_hat.trainable_variables)  
    dresidue_ic = tape.gradient(residue_ic,z_hat.trainable_variables)
    
    del tape
    return dresidue_pde,dresidue_ic

# %%
dresidue_pde,dresidue_ic = calc_imbalance(t)
for i in range(len(tf.shape_n(z_hat.trainable_variables))):
    plt.title('Gradients for parameter '+str(i))
    plt.plot(tf.reshape(dresidue_pde[i],(-1)), label ='pde_res'+str(i) )
    plt.plot(tf.reshape(dresidue_ic[i],(-1)),label ='ics_res'+str(i))
    plt.legend()
    plt.show()

# %%
sns.displot(tf.reshape(dresidue_pde[0],(-1)), kind='kde',label=r'$\nabla_\theta \lambda_{u_b} \mathcal{L}_{u_b}$')
sns.displot(tf.reshape(dresidue_ic[0],(-1)), kind='kde')
plt.show()
# Out:
# /tmp/ipykernel_12082/3152432843.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(tf.reshape(dresidue_ic[0],(-1)), kind='kde')

# %%
def mix_optimizers():
    shapes = tf.shape_n(z_hat.trainable_variables)
    length_shapes = len(shapes)
    count = 0
    idx = []
    part = []

    loss_pde,loss_ic = z_hat.loss(t)
    total_loss = loss_pde + loss_ic
    print(f'Initial loss : {total_loss}')


    for i in range(length_shapes):
        n = np.product(shapes[i])
        idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
        count += n   
        part.extend([i]*n)

    def update_weights(OneD):
        params = tf.dynamic_partition(OneD, part, length_shapes)
        for i, (shape, param) in enumerate(zip(shapes, params)):
            z_hat.trainable_variables[i].assign(tf.reshape(param, shape))

    def flatten_the_parameters(weights):
        return tf.dynamic_stitch(idx, weights) 

    @tf.function
    def value_and_gradient(flat_weights):
        #update weights 
        update_weights(flat_weights)
        with tf.GradientTape() as g:
            loss_pde,loss_ic = z_hat.loss(t)
            los = loss_pde + loss_ic
        grad = g.gradient(los, z_hat.trainable_variables) 
        flattend_grad = flatten_the_parameters(grad) #converts from multDim to 1D
        return los, flattend_grad  


    start_time2 = time.time()

    flat_parameters = flatten_the_parameters(z_hat.trainable_variables)
    start = tf.constant(flat_parameters)  # Starting point for the search.
    grads_lists = []
    optim_results = tfp.optimizer.lbfgs_minimize(
      value_and_gradient, initial_position=start, tolerance=1.0e-20, max_iterations=5000)
    grad_curr = tf.norm(optim_results.objective_gradient,ord=np.inf)
    grads_lists.append(grad_curr)

    while  optim_results.converged.numpy() == False:
        optim_results = tfp.optimizer.lbfgs_minimize(
      value_and_gradient, initial_position=start, max_iterations=5000)
        print('converged:', optim_results.converged.numpy())
        print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
        print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
        print('')
        new_grad = tf.norm(optim_results.objective_gradient,ord=np.inf)

        if new_grad == grads_lists[-1]:
            print('NO change')
#             train_update_step(t,10000,True)
#             mix_optimizers()
            break



    print('converged:', optim_results.converged.numpy())
    print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
    print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
    update_weights(optim_results.position)

    loss_pde,loss_ic = z_hat.loss(t)
    los = loss_pde + loss_ic
    print('loss',los)
    print('Times : ',time.time()-start_time2,'\n')      


def train_update_step(t,epochs,rerun):
    losses =[]
    loss_decrease = []
    check_decrease = 0
    initial_loss = train_and_update(t).numpy()
    if rerun:
        best_so_far = initial_loss
    else:
        best_so_far =  np.inf
    
    
    
    best_so_far =  np.inf
    print(f'initial loss : {initial_loss}')
    losses.append(initial_loss)
    for epoch in tnrange(epochs):
        loss = train_and_update(t).numpy()

        if loss < losses[-1]:
            if loss < best_so_far:
                best_so_far = loss
                loss_decrease.append(loss)
#                 print(f'******************best so far is updated to :{best_so_far}********************')
                z_hat.save_weights('best_model')
                check_decrease = loss  

        if np.isnan(loss):
            print(f'Loss :{loss}')
            break

        losses.append(loss)

        if epoch%1000==0:
            print(f'loss for epoch {epoch} : {loss} best so far {best_so_far}') 
            print(end = ".")

    z_hat.load_weights('best_model')
    
    mix_optimizers()

    return losses,loss_decrease

# %%
losses,loss_decrease = train_update_step(t,10000,True)
# Out:
# initial loss : 0.00025859480956569314
#   0%|          | 0/10000 [00:00<?, ?it/s]
# loss for epoch 0 : 0.001504106679931283 best so far inf
# .loss for epoch 1000 : 0.0001784418273018673 best so far 0.0001768474030541256
# .loss for epoch 2000 : 7.464204099960625e-05 best so far 6.958856101846322e-05
# .loss for epoch 3000 : 3.197248952346854e-05 best so far 2.226226388302166e-05
# .loss for epoch 4000 : 2.536009378673043e-05 best so far 1.2540625903056934e-05
# .loss for epoch 5000 : 8.75069326866651e-06 best so far 8.4590019469033e-06
# .loss for epoch 6000 : 7.14971829438582e-05 best so far 6.015750841470435e-06
# .loss for epoch 7000 : 7.72064049670007e-06 best so far 3.7518209410336567e-06
# .loss for epoch 8000 : 1.0616122381179594e-05 best so far 2.3211907773657003e-06
# .loss for epoch 9000 : 5.925996447331272e-05 best so far 1.8265725429955637e-06
# .Initial loss : 1.850715079854126e-06
# converged: False
# num_iterations 2 and evaluations 30
# gradient:0.0020278338342905045
#
# NO change
# converged: False
# num_iterations 2 and evaluations 30
# gradient:0.0020278338342905045
# loss tf.Tensor(1.2699098e-06, shape=(), dtype=float32)
# Times :  0.5463178157806396

# %%
# plt.plot(losses)
plt.plot(loss_decrease)

# %%
true_v = lambda t: g*t + v0
plt.plot(t,true_v(t),'o')
plt.plot(t, z_hat(t))
plt.legend(['True','NN'])

# %%
tf.reduce_max(tf.abs(tf.reshape(dresidue_pde[0],(-1))))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=7.2677407>

# %%
tf.reduce_mean(tf.abs(tf.reshape(dresidue_ic[0],(-1))))+1e-10
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1e-10>

# %%
dresidue_pde,dresidue_ic = calc_imbalance(t)
lamda1 = 1.
alpha = 1.

for i in range(len(tf.shape_n(z_hat.trainable_variables))):
    num = tf.reduce_max(tf.abs(tf.reshape(dresidue_pde[i],(-1))))
    den = tf.reduce_mean(tf.abs(tf.reshape(dresidue_ic[i],(-1))))+1e-10
    
    lambda_hat = num/den
    
    lamda1 = (1.-alpha)*lamda1 + alpha*lambda_hat
    
    
    
    plt.title('Gradients for parameter '+str(i))
    plt.plot(tf.reshape(dresidue_pde[i],(-1)), label ='pde_res'+str(i) )
    plt.plot(tf.reshape(dresidue_ic[i],(-1)),label ='ics_res'+str(i))
    plt.legend()
    plt.show()
    
    plt.title('modified Gradients for parameter '+str(i))
    plt.plot(tf.reshape(dresidue_pde[i],(-1)), label ='mod_pde_res'+str(i) )
    plt.plot(tf.reshape(lamda1*dresidue_ic[i],(-1)),label ='mod_ics_res'+str(i))
    plt.legend()
    plt.show()

# %%
mix_optimizers()
# Out:
# Initial loss : 2.171615051338449e-05
# converged: False
# num_iterations 5 and evaluations 74
# gradient:0.006464626640081406
#
# NO change
# converged: False
# num_iterations 5 and evaluations 74
# gradient:0.006464626640081406
# loss tf.Tensor(1.9105498e-06, shape=(), dtype=float32)
# Times :  1.1226909160614014

# %%
train_and_update(t).numpy()
# Out:
# 1.6603051e-05

# %%
losses,loss_decrease = train_whole_set(t,1000, False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_7079/2833245924.py in <module>
# ----> 1 losses,loss_decrease = train_whole_set(t,1000, False)
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /tmp/__autograph_generated_filel6ygobi1.py in tf__train_whole_set(t, epochs, rerun)
#      11                 loss_decrease = []
#      12                 check_decrease = 0
# ---> 13                 initial_loss = ag__.converted_call(ag__.ld(train_and_update), (ag__.ld(t),), None, fscope)
#      14
#      15                 def get_state():
#
# AssertionError: in user code:
#
#     File "/tmp/ipykernel_7079/2416262649.py", line 8, in train_whole_set  *
#         initial_loss = train_and_update(t)
#
#     AssertionError: Called a function referencing variables which have been deleted. This likely means that function-local variables were created and not referenced elsewhere in the program. This is generally a mistake; consider storing variables in an object attribute on first call.

# %%
ll = 00

if ll: 
    print('Yes')
else:
    print('No')
# Out:
# No

# %%
tf.shape_n(z_hat.trainable_variables)
# Out:
# [<tf.Tensor: shape=(2,), dtype=int32, numpy=array([ 1, 30], dtype=int32)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([30], dtype=int32)>,
#  <tf.Tensor: shape=(2,), dtype=int32, numpy=array([30, 30], dtype=int32)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([30], dtype=int32)>,
#  <tf.Tensor: shape=(2,), dtype=int32, numpy=array([30, 30], dtype=int32)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([30], dtype=int32)>,
#  <tf.Tensor: shape=(2,), dtype=int32, numpy=array([30,  1], dtype=int32)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([30], dtype=int32)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([30], dtype=int32)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([30], dtype=int32)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([30], dtype=int32)>]

# %%
class PINN:
    def __init__(self, t, model,z_initm,optim):
        self.model = model
        self.t = t
        self.x_init = z_init[0]
        self.y_init = z_init[1]
        self.optim = optim

        
    def function_and_derivatives(self,t):
        '''
        Calculate the derivatives and function that correspond to the ode

        input:
                t : independent variant

        output:
                value and corresponding derivative

        '''
        
#         z = u + iv
        with tf.GradientTape() as tape:
            tape.watch(t)         
            v = self.model(t)
        dvdt = tf.cast(tape.gradient(v,t),dtype=tf.float32)  
        return u,dvdt
    
    def equations(self, u,v,dudt,dvdt):
    #     derivatives must be dtype tf.float32
    #     dzdt = iz(t)
        dzdt = tf.complex(dudt,dvdt) # dzdt = dudt + idvdt . 
        z = tf.complex(u,v)
        rhs = z*1.j

    #     real(LHS)-Real(RHS) = -Imag(LHS)+Img(RHS) Equation from PINN paper

        f_real = tf.math.real(dzdt) - tf.math.real(rhs) # = real(LHS)-Real(RHS)
        f_imag = -tf.math.imag(dzdt) + tf.math.imag(rhs) # = -Imag(LHS)+Img(RHS)
        return f_real,f_imag
        
    def ode_ic(self,t):
        u,v, dudt,dvdt  = self.get_derivatives(t)
        f_real,f_imag = self.equations(u,v, dudt,dvdt)
        u1 =  f_real   #residual of real numbers
        u2 =  f_imag   #residual of Imag numbers
#         Initial conditions
        u0,v0,_,_ = self.get_derivatives(10**(-10)*tf.ones_like(t))
#        
        u3 = u0 - self.x_init
        u4 = v0  - self.y_init

        return u1,u2,u3,u4
        
    def loss(self,t):
        u1,u2,u3,u4 = self.ode_ic(t)
        residual_x  = tf.reduce_mean(tf.square(u1))
        residual_y  = tf.reduce_mean(tf.square(u2))
        mse_x0_real = tf.reduce_mean(tf.square(u3))
        mse_y0_imag = tf.reduce_mean(tf.square(u4))
#         print(f'mse_x :{residual_x}, mse_y : {residual_y}')
#         print('Same order as bc')
#         print(f'mse_x0 :{mse_x0_real}, mse_y0 : {mse_y0_imag}')
        return residual_x,residual_y,mse_x0_real,mse_y0_imag
    
    def lambda_hat(self, grad_residue_ode, grad_residue_ic):
        numerator   = tf.math.reduce_max(tf.math.abs(grad_residue_ode))
        denominator = tf.reduce_mean(tf.math.abs(grad_residue_ic))
        return numerator/denominator
        
    def annealing_update(self,t):    
        alpha = tf.constant(0.9, tf.float32)
        eta = tf.constant(10**(-3), tf.float32)
        
        lambda_real = tf.constant(1., tf.float32)
        lambda_imag = tf.constant(1., tf.float32)
        
               
        
        with tf.GradientTape(persistent=True) as tape:
            residual_x,residual_y,mse_x0_real,mse_y0_imag = self.loss(t)
            total_loss = residual_x + mse_x0_real*lambda_real +   residual_y + mse_y0_imag*lambda_imag 
#             print('first loss',new_loss)
            
        grad_residual_x = tape.gradient(residual_x,self.model.trainable_variables)  
        grad_residual_y = tape.gradient(residual_y,self.model.trainable_variables)
        
        grad_mse_x0_real = tape.gradient(mse_x0_real,self.model.trainable_variables)
        grad_mse_y0_imag = tape.gradient(mse_y0_imag,self.model.trainable_variables)
        del tape
        
#         return grad_residual_x,grad_residual_y,grad_mse_x0_real,grad_mse_y0_imag
        

        
        S = len(tf.shape_n(self.model.trainable_variables))
        
            
        max_grad_res_list_real = []
        max_grad_res_list_imag = []
        max_grad_res_list_real_bc =[]
        max_grad_res_list_imag_bc = []
        
        for n in range(S):
#             if tf.size(grad_residual_x[n].shape) == 2 and grad_residual_x[n].shape[0] == 1:
#                 plt.plot(grad_residual_x[n][0],label = 'grad_res')
#                 plt.plot(grad_mse_x0_real[n][0],label = 'grad_IC')
#                 plt.title('layer_corrected = '+str(n))
#                 plt.legend()
#                 plt.show()
            
#             print(f'shapes:{grad_residual_x[n].shape} \n reduce_prod :{tf.reduce_prod(grad_residual_x[n].shape)}')
            max_grad_res_list_real.append( tf.reduce_max(tf.math.abs(grad_residual_x[n])))
            max_grad_res_list_imag.append( tf.reduce_max(tf.math.abs(grad_residual_y[n])))

            max_grad_res_list_real_bc.append( tf.reduce_mean(tf.math.abs(grad_mse_x0_real[n])))
            max_grad_res_list_imag_bc.append( tf.reduce_mean(tf.math.abs(grad_mse_y0_imag[n])) )
            
        lambda_residue_hat_real = tf.reduce_max(max_grad_res_list_real) / tf.reduce_mean(max_grad_res_list_real_bc)
        lambda_residue_hat_imag = tf.reduce_max(max_grad_res_list_imag) / tf.reduce_mean(max_grad_res_list_imag_bc)
        
        lambda_real = (1. - alpha)*lambda_real + alpha*lambda_residue_hat_real
        lambda_imag = (1. - alpha)*lambda_imag + alpha*lambda_residue_hat_imag 

        total_loss_updated = residual_x + mse_x0_real*lambda_real  + residual_y + mse_y0_imag*lambda_imag
#         print(f'loss residue_real :{residual_x} ,loss residue_imag :{residual_y}' )
#         print('Old loss_bc')
#         print(f'loss residue_real_bc :{mse_x0_real} ,loss residue_imag_bc :{mse_y0_imag}' )
#         print('New loss_bc')
#         print(f'loss residue_real_bc :{mse_x0_real*lambda_real} ,loss residue_imag_bc :{mse_y0_imag*lambda_imag}' )        
#         print(f'New lambda_real :{lambda_real}...New lambda_imag :{lambda_imag} ')
        return total_loss_updated

    @tf.function
    def train_and_update(self,t):
        with tf.GradientTape() as tape:
            los  = self.annealing_update(t)
        dlossdpa = tape.gradient(los,self.model.trainable_variables) 
        self.optim.apply_gradients(zip(dlossdpa, self.model.trainable_variables))
        return los

    def train_whole_set(self, t,epochs, rerun):     
        losses =[]
        loss_decrease = []
        check_decrease = 0
        initial_loss = self.train_and_update(t).numpy()
        if rerun:
            best_so_far = initial_loss
        else:
            best_so_far =  np.inf
        print(f'initial loss : {initial_loss}')
        losses.append(initial_loss)

        for epoch in tnrange(epochs):
            loss = self.train_and_update(t).numpy()

            if loss < losses[-1]:
                if loss < best_so_far:
                    best_so_far = loss
                    loss_decrease.append(loss)
                    self.model.save_weights('best_model')
                    check_decrease = loss

            

            if np.isnan(loss):
                print(f'Loss :{loss}')
                break
            
            losses.append(loss)

            if epoch%500==0:
                print(f'loss for epoch {epoch} : {loss} best so far {best_so_far}') 
        #         print(end = ".")

        self.model.load_weights('best_model')
        

#             print(f'Final loss : {loss}  best so far {best_so_far}') 
#             print(f'Last decrease : {check_decrease}')
        return losses,loss_decrease


    def train_lbfgs(self,model,loss,t):
        # Quasi Newton to improve the result : model == updated model
        print(f'\n Initial loss : {loss(t)}')
        shapes = tf.shape_n(model.trainable_variables)
        length_shapes = len(shapes)
        count = 0
        idx = []
        part = []
        for i in range(length_shapes):
            n = np.product(shapes[i])
            idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
            count += n   
            part.extend([i]*n)

        def update_weights(OneD):
            params = tf.dynamic_partition(OneD, part, length_shapes)
            for i, (shape, param) in enumerate(zip(shapes, params)):
                model.trainable_variables[i].assign(tf.reshape(param, shape))

        def flatten_the_parameters(weights):
            return tf.dynamic_stitch(idx, weights) 

        @tf.function
        def value_and_gradient(flat_weights):
            #update weights 
            update_weights(flat_weights)
            with tf.GradientTape() as g:
                los = loss(t)

            grad = g.gradient(los, model.trainable_variables) 
            flattend_grad = flatten_the_parameters(grad) #converts from multDim to 1D
            return los, flattend_grad

        start_time2 = time.time()

        flat_parameters = flatten_the_parameters(model.trainable_variables)
        start = tf.constant(flat_parameters)  # Starting point for the search.
        grads_lists = []
        optim_results = tfp.optimizer.lbfgs_minimize(
          value_and_gradient, initial_position=start, tolerance=1.0e-20, max_iterations=5000)
        grad_curr = tf.norm(optim_results.objective_gradient,ord=np.inf)
        grads_lists.append(grad_curr)

        while  optim_results.converged.numpy() == False:
            optim_results = tfp.optimizer.lbfgs_minimize(
          value_and_gradient, initial_position=start, max_iterations=5000)
            print('converged:', optim_results.converged.numpy())
            print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
            print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
            print('')
            new_grad = tf.norm(optim_results.objective_gradient,ord=np.inf)

            if new_grad == grads_lists[-1]:
                break



        print('converged:', optim_results.converged.numpy())
        print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
        print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
        update_weights(optim_results.position)

    #         print('initial loss',initial_loss_after)
        print('loss',loss(t))
        print('Times : ',time.time()-start_time2,'\n')      
















#         return total_loss, total_loss_updated
#             print(f'Layer no : {n} \n Corresponding derivative :\n {grad_residual_x[n]} ')
#             print('====================================================================== \n')
                
                
        '''       Before the website : https://github.com/PredictiveIntelligenceLab/GradientPathologiesPINNs/blob/master/Helmholtz/Helmholtz2D_model_tf.py

                print(f'shape residue with 0 {grad_residual_x[n][0].shape} \n Without zero {grad_residual_x[n].shape}')
                lambda_hat_real = self.lambda_hat(grad_residual_x[n][0],grad_mse_x0_real[n][0])
                lambda_hat_imag = self.lambda_hat(grad_residual_y[n][0],grad_mse_y0_imag[n][0])

                print(f'lambda_hat_real :{lambda_hat_real} \n lambda_hat_imag {lambda_hat_imag}')


                lambda_real = (1. - alpha)*lambda_real + alpha*lambda_hat_real
                lambda_imag = (1. - alpha)*lambda_imag + alpha*lambda_hat_imag 

                update_real = eta*(grad_residual_x[n][0]+lambda_real*grad_mse_x0_real[n][0])
                update_imag = eta*(grad_residual_y[n][0]+lambda_imag*grad_mse_y0_imag[n][0]) 
                total_update = update_real + update_imag
                print(f'update :{total_update.shape,self.model.trainable_variables[n].shape }')

                total_update = tf.reshape(total_update,self.model.trainable_variables[n].shape)
#                 print(f'update :{total_update.shape,self.model.trainable_variables[n].shape }')
                
                
                
                
                
                
            else: 
                plt.plot(grad_residual_x[n],label = 'grad_res')
                plt.plot(grad_mse_x0_real[n],label = 'grad_IC')
                plt.title('layer = '+str(n))
                plt.legend()
                plt.show()
                
                print(f'shape residue with 0 {grad_residual_x[n][0].shape} \n Without zero {grad_residual_x[n].shape}')
            
            
                lambda_hat_real = self.lambda_hat(grad_residual_x[n],grad_mse_x0_real[n])
                lambda_hat_imag = self.lambda_hat(grad_residual_y[n],grad_mse_y0_imag[n])

                print(f'lambda_hat_real :{lambda_hat_real} \n lambda_hat_imag {lambda_hat_imag}')


                lambda_real = (1. - alpha)*lambda_real + alpha*lambda_hat_real
                lambda_imag = (1. - alpha)*lambda_imag + alpha*lambda_hat_imag 

                update_real = eta*(grad_residual_x[n]+lambda_real*grad_mse_x0_real[n])
                update_imag = eta*(grad_residual_y[n]+lambda_imag*grad_mse_y0_imag[n]) 
                total_update = update_real + update_imag
            
            self.model.trainable_variables[n].assign_sub(total_update)
            
            
            if tf.size(grad_residual_x[n].shape) == 2:
                plt.plot(grad_residual_x[n][0],label = 'After_grad_res')
                plt.plot(lambda_real*grad_mse_x0_real[n][0],label = 'Aftergrad_IC')
                plt.title('layer_corrected = '+str(n))
                plt.legend()
                plt.show()
            else:        
                plt.plot(grad_residual_x[n],label = 'After_grad_res')
                plt.plot(lambda_real*grad_mse_x0_real[n],label = 'After_grad_IC')
                plt.title('layer = '+str(n))
                plt.legend()
                plt.show()

        residual_x,residual_y,mse_x0_real,mse_y0_imag = self.loss(t)
        new_loss = residual_x + mse_x0_real*lambda_real +   residual_y + mse_y0_imag*lambda_imag
        '''        

#             print('updated_loss ',new_loss )
#         return new_loss    
            
#     def train_with_annealing_update(self,iterations, t):
#         loss_f = []
#         for i in tnrange(iterations):
#             loss_f.append(self.annealing_update(t))
#         return loss_f

# %%
t = tf.linspace(0,1,10**5)[:,tf.newaxis]
t.shape
optim = tf.keras.optimizers.Adam()
z_hat = Z_approx(num_of_hid_layers = 3, units_per_layer = 30, num_out=2, initialization = 0,activation = 'mish')
z_hat.build(t.shape)
z_hat(t)
x_int = tf.constant(1.0, dtype = tf.float32)
y_int = tf.constant(0.0, dtype = tf.float32)

z_init = tf.constant(np.array([x_int,y_int]), dtype=tf.float32)
pinn = PINN(t,z_hat,z_init, optim)

pinn.annealing_update(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=16.001783>

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_16980/2351219987.py in <module>
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !pip install seaborn
# Out:
# /bin/bash: /home/tshegofatso/miniconda3/envs/tf_38gpu/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 656.8 kB/s eta 0:00:000:00:010:00:01:01
# Collecting pandas>=0.25
#   Downloading pandas-1.5.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 185.1 kB/s eta 0:00:00m eta 0:00:010:00:02
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/tshegofatso/.local/lib/python3.8/site-packages (from seaborn) (1.21.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/tshegofatso/.local/lib/python3.8/site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tshegofatso/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tshegofatso/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/tshegofatso/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/tshegofatso/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/tshegofatso/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tshegofatso/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/tshegofatso/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/tshegofatso/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.6)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.7-py2.py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 188.7 kB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: six>=1.5 in /home/tshegofatso/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: pytz, pandas, seaborn
# Successfully installed pandas-1.5.2 pytz-2022.7 seaborn-0.12.2

# %%
import seaborn as sb

# %%
loss,best_loss = pinn.train_whole_set(t,200,False)
# Out:
# initial loss : 16.00178337097168
#   0%|          | 0/200 [00:00<?, ?it/s]
# loss for epoch 0 : 11.845352172851562 best so far 11.845352172851562
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_16980/3033020014.py in <module>
# ----> 1 loss,best_loss = pinn.train_whole_set(t,200,False)
#
# /tmp/ipykernel_16980/137667964.py in train_whole_set(self, t, epochs, rerun)
#     157
#     158         for epoch in tnrange(epochs):
# --> 159             loss = self.train_and_update(t).numpy()
#     160
#     161             if loss < losses[-1]:
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2494       (graph_function,
#    2495        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496     return graph_function._call_flat(
#    2497         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2498
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1860         and executing_eagerly):
#    1861       # No tape is watching; skip to running the function.
# -> 1862       return self._build_call_outputs(self._inference_function.call(
#    1863           ctx, args, cancellation_manager=cancellation_manager))
#    1864     forward_backward = self._select_forward_and_backward_functions(
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
plt.plot(loss)
plt.plot(best_loss)

# %%
best_loss[-1]
# Out:
# 0.065613374

# %%
model= z_hat
model.trainable_variables;

# %%
pinn.train_and_update(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.102256276>

# %%
shapes = tf.shape_n(model.trainable_variables)
length_shapes = len(shapes)
count = 0
idx = []
part = []



for i in range(length_shapes):
    n = np.product(shapes[i])
    idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
    count += n   
    part.extend([i]*n)
    
def update_weights(OneD):
    params = tf.dynamic_partition(OneD, part, length_shapes)
    for i, (shape, param) in enumerate(zip(shapes, params)):
        model.trainable_variables[i].assign(tf.reshape(param, shape))

def flatten_the_parameters(weights):
    return tf.dynamic_stitch(idx, weights) 

@tf.function
def value_and_gradient(flat_weights):
    #update weights 
    update_weights(flat_weights)
    with tf.GradientTape() as g:
        los = pinn.train_and_update(t)

    grad = g.gradient(los, model.trainable_variables) 
    flattend_grad = flatten_the_parameters(grad) #converts from multDim to 1D
    return los, flattend_grad

# %%
value_and_gradient(flatten_the_parameters(model.trainable_variables))

# %%
flat_parameters = flatten_the_parameters(model.trainable_variables)
start = tf.constant(flat_parameters)  # Starting point for the search.
grads_lists = []
optim_results = tfp.optimizer.lbfgs_minimize(
  value_and_gradient, initial_position=start, tolerance=1.0e-20, max_iterations=5000)
# grad_curr = tf.norm(optim_results.objective_gradient,ord=np.inf)
# grads_lists.append(grad_curr)

# %%
optim_results.converged.numpy()

# %%
while  optim_results.converged.numpy() == False:
    optim_results = tfp.optimizer.lbfgs_minimize(
  value_and_gradient, initial_position=start)
    print('converged:', optim_results.converged.numpy())
    print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
    print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
    print('')
    new_grad = tf.norm(optim_results.objective_gradient,ord=np.inf)

    if new_grad == grads_lists[-1]:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12107/4020062763.py in <module>
#       1 while  optim_results.converged.numpy() == False:
# ----> 2     optim_results = tfp.optimizer.lbfgs_minimize(
#       3   value_and_gradient, initial_position=start, max_iterations=5000)
#       4     print('converged:', optim_results.converged.numpy())
#       5     print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/lbfgs.py in minimize(value_and_gradients_function, initial_position, previous_optimizer_results, num_correction_pairs, tolerance, x_tolerance, f_relative_tolerance, initial_inverse_hessian_estimate, max_iterations, parallel_iterations, stopping_condition, max_line_search_iterations, f_absolute_tolerance, name)
#     283       initial_state = previous_optimizer_results
#     284
# --> 285     return tf.while_loop(
#     286         cond=_cond,
#     287         body=_body,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     627                   func.__module__, arg_name, arg_value, 'in a future version'
#     628                   if date is None else ('after %s' % date), instructions)
# --> 629       return func(*args, **kwargs)
#     630
#     631     doc = _add_deprecated_arg_value_notice_to_docstring(
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2511
#    2512   """
# -> 2513   return while_loop(
#    2514       cond=cond,
#    2515       body=body,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2760                                               list(loop_vars))
#    2761       while cond(*loop_vars):
# -> 2762         loop_vars = body(*loop_vars)
#    2763         if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2764           packed = True
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/lbfgs.py in _body(current_state)
#     257       # search direction.
#     258
# --> 259       next_state = bfgs_utils.line_search_step(
#     260           current_state, value_and_gradients_function, search_direction,
#     261           tolerance, f_relative_tolerance, x_tolerance, stopping_condition,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/bfgs_utils.py in line_search_step(state, value_and_gradients_function, search_direction, grad_tolerance, f_relative_tolerance, x_tolerance, stopping_condition, max_iterations, f_absolute_tolerance)
#     207                            full_gradient=state.objective_gradient)
#     208   inactive = state.failed | state.converged
# --> 209   ls_result = hager_zhang(
#     210       line_search_value_grad_func,
#     211       initial_step_size=_broadcast(1, state.position),
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in hager_zhang(value_and_gradients_function, initial_step_size, value_at_initial_step, value_at_zero, converged, threshold_use_approximate_wolfe_condition, shrinkage_param, expansion_param, sufficient_decrease_param, curvature_param, max_iterations, name)
#     272
#     273     init_active = ~init_interval.failed & ~init_interval.converged
# --> 274     return prefer_static.cond(
#     275         tf.reduce_any(init_active),
#     276         _apply_bracket_and_search,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/internal/prefer_static.py in cond(pred, true_fn, false_fn, name)
#     254   if pred_value is not None:
#     255     if pred_value:
# --> 256       return true_fn()
#     257     else:
#     258       return false_fn()
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in _apply_bracket_and_search()
#     266     def _apply_bracket_and_search():
#     267       """Bracketing and searching to do for valid inputs."""
# --> 268       return _bracket_and_search(
#     269           value_and_gradients_function, init_interval, f_lim, max_iterations,
#     270           shrinkage_param, expansion_param, sufficient_decrease_param,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in _bracket_and_search(value_and_gradients_function, init_interval, f_lim, max_iterations, shrinkage_param, expansion_param, sufficient_decrease_param, curvature_param)
#     369       right=bracket_result.right)
#     370
# --> 371   return _line_search_after_bracketing(
#     372       value_and_gradients_function, line_search_args, init_interval.left,
#     373       f_lim, max_iterations, sufficient_decrease_param, curvature_param,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in _line_search_after_bracketing(value_and_gradients_function, search_interval, val_0, f_lim, max_iterations, sufficient_decrease_param, curvature_param, shrinkage_param)
#     496     return [next_args._replace(converged=next_args.converged | interval_shrunk)]
#     497
# --> 498   return tf.while_loop(
#     499       cond=_loop_cond,
#     500       body=_loop_body,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     627                   func.__module__, arg_name, arg_value, 'in a future version'
#     628                   if date is None else ('after %s' % date), instructions)
# --> 629       return func(*args, **kwargs)
#     630
#     631     doc = _add_deprecated_arg_value_notice_to_docstring(
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2511
#    2512   """
# -> 2513   return while_loop(
#    2514       cond=cond,
#    2515       body=body,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2760                                               list(loop_vars))
#    2761       while cond(*loop_vars):
# -> 2762         loop_vars = body(*loop_vars)
#    2763         if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2764           packed = True
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in _loop_body(curr_interval)
#     487           lambda: inner_bisect_args)
#     488
# --> 489     next_args = prefer_static.cond(
#     490         tf.reduce_any(should_check_shrinkage),
#     491         _do_check_shrinkage,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/internal/prefer_static.py in cond(pred, true_fn, false_fn, name)
#     254   if pred_value is not None:
#     255     if pred_value:
# --> 256       return true_fn()
#     257     else:
#     258       return false_fn()
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in _do_check_shrinkage()
#     482             needs_inner_bisect, f_lim)
#     483
# --> 484       return prefer_static.cond(
#     485           tf.reduce_any(needs_inner_bisect),
#     486           _apply_inner_bisect,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/internal/prefer_static.py in cond(pred, true_fn, false_fn, name)
#     254   if pred_value is not None:
#     255     if pred_value:
# --> 256       return true_fn()
#     257     else:
#     258       return false_fn()
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in _apply_inner_bisect()
#     478
#     479       def _apply_inner_bisect():
# --> 480         return _line_search_inner_bisection(
#     481             value_and_gradients_function, inner_bisect_args,
#     482             needs_inner_bisect, f_lim)
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/linesearch/hager_zhang.py in _line_search_inner_bisection(value_and_gradients_function, search_interval, active, f_lim)
#     510   """Performs bisection and updates the interval."""
#     511   midpoint = (search_interval.left.x + search_interval.right.x) / 2
# --> 512   val_mid = value_and_gradients_function(midpoint)
#     513   is_valid_mid = hzl.is_finite(val_mid)
#     514
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow_probability/python/optimizer/bfgs_utils.py in _restricted_func(t)
#     308     pt = position + t[..., tf.newaxis] * direction
#     309     t = _broadcast(t, position)
# --> 310     objective_value, gradient = value_and_gradients_function(pt)
#     311     return ValueAndGradient(
#     312         x=t,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2494       (graph_function,
#    2495        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496     return graph_function._call_flat(
#    2497         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2498
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1860         and executing_eagerly):
#    1861       # No tape is watching; skip to running the function.
# -> 1862       return self._build_call_outputs(self._inference_function.call(
#    1863           ctx, args, cancellation_manager=cancellation_manager))
#    1864     forward_backward = self._select_forward_and_backward_functions(
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
    def train_lbfgs(self,model,loss,t):
        # Quasi Newton to improve the result : model == updated model
        print(f'\n Initial loss : {loss(t)}')
        shapes = tf.shape_n(model.trainable_variables)
        length_shapes = len(shapes)
        count = 0
        idx = []
        part = []
        for i in range(length_shapes):
            n = np.product(shapes[i])
            idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
            count += n   
            part.extend([i]*n)

        def update_weights(OneD):
            params = tf.dynamic_partition(OneD, part, length_shapes)
            for i, (shape, param) in enumerate(zip(shapes, params)):
                model.trainable_variables[i].assign(tf.reshape(param, shape))

        def flatten_the_parameters(weights):
            return tf.dynamic_stitch(idx, weights) 

        @tf.function
        def value_and_gradient(flat_weights):
            #update weights 
            update_weights(flat_weights)
            with tf.GradientTape() as g:
                los = loss(t)

            grad = g.gradient(los, model.trainable_variables) 
            flattend_grad = flatten_the_parameters(grad) #converts from multDim to 1D
            return los, flattend_grad

        start_time2 = time.time()

        flat_parameters = flatten_the_parameters(model.trainable_variables)
        start = tf.constant(flat_parameters)  # Starting point for the search.
        grads_lists = []
        optim_results = tfp.optimizer.lbfgs_minimize(
          value_and_gradient, initial_position=start, tolerance=1.0e-20, max_iterations=5000)
        grad_curr = tf.norm(optim_results.objective_gradient,ord=np.inf)
        grads_lists.append(grad_curr)

        while  optim_results.converged.numpy() == False:
            optim_results = tfp.optimizer.lbfgs_minimize(
          value_and_gradient, initial_position=start, max_iterations=5000)
            print('converged:', optim_results.converged.numpy())
            print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
            print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
            print('')
            new_grad = tf.norm(optim_results.objective_gradient,ord=np.inf)

            if new_grad == grads_lists[-1]:
                break



        print('converged:', optim_results.converged.numpy())
        print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
        print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
        update_weights(optim_results.position)

    #         print('initial loss',initial_loss_after)
        print('loss',loss(t))
        print('Times : ',time.time()-start_time2,'\n')
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.0005431446>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.0033890824>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.16977184>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=1.3397465e-07>)

# %%
tf.math.reduce_sum(pinn.loss(t))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.00033580427>

# %%
@tf.function
def train_and_update(t):
    with tf.GradientTape() as tape:
        los  = pinn.annealing_update(t)
    dlossdpa = tape.gradient(los,z_hat.trainable_variables) 
    optim.apply_gradients(zip(dlossdpa, z_hat.trainable_variables))
    return los

# %%
print(f'initial loss :{pinn.annealing_update(t)}')
for i in tnrange(20):
    new_loss = train_and_update(t)
    print(f'New loss {new_loss.numpy()}')
# Out:
# initial loss :2.548427104949951
#   0%|          | 0/20 [00:00<?, ?it/s]
# New loss 2.548427104949951
# New loss 2.4955286979675293
# New loss 1.6956639289855957
# New loss 1.2861180305480957
# New loss 1.8460146188735962
# New loss 1.7802503108978271
# New loss 1.156970500946045
# New loss 1.5392205715179443
# New loss 1.9083064794540405
# New loss 1.5655509233474731
# New loss 0.751955509185791
# New loss 1.3040719032287598
# New loss 1.3341604471206665
# New loss 0.9263567328453064
# New loss 0.9219312071800232
# New loss 1.0784651041030884
# New loss 0.7662678360939026
# New loss 0.8335310816764832
# New loss 1.1445897817611694
# New loss 1.2296959161758423

# %%
class PINN:
    def __init__(self, t, model,z_init,optim):
        self.model = model
        self.t = t
        self.x_init = z_init[0]
        self.y_init = z_init[1]
        self.optim = optim
        
        n_ic = tf.constant(2, tf.int32)
        lambdas = tf.Variable(tf.ones(n_ic),)
        lambdas_hat = tf.Variable(tf.zeros(n_ic))

        
    def get_derivatives(self,t):
        '''
        Calculate the derivatives and function that correspond to the ode

        input:
                t : independent variant

        output:
                value and corresponding derivative

        '''
        
#         z = u + iv
        with tf.GradientTape(persistent=True) as tape:
            tape.watch(t)         
            u = self.model(t)[:,0:1]
            v = self.model(t)[:,1:2]
        dudt = tf.cast(tape.gradient(u,t),dtype=tf.float32)
        dvdt = tf.cast(tape.gradient(v,t),dtype=tf.float32)  
        del tape
        
        return u,v, dudt,dvdt
    
    def equations(self, u,v,dudt,dvdt):
    #     derivatives must be dtype tf.float32
    #     dzdt = iz(t)
        dzdt = tf.complex(dudt,dvdt) # dzdt = dudt + idvdt . 
        z = tf.complex(u,v)
        rhs = z*1.j

    #     real(LHS)-Real(RHS) = -Imag(LHS)+Img(RHS) Equation from PINN paper

        f_real = tf.math.real(dzdt) - tf.math.real(rhs) # = real(LHS)-Real(RHS)
        f_imag = -tf.math.imag(dzdt) + tf.math.imag(rhs) # = -Imag(LHS)+Img(RHS)
        return f_real,f_imag
        
    def ode_ic(self,t):
        u,v, dudt,dvdt  = self.get_derivatives(t)
        f_real,f_imag = self.equations(u,v, dudt,dvdt)
        u1 =  f_real   #residual of real numbers
        u2 =  f_imag   #residual of Imag numbers
#         Initial conditions
        u0,v0,_,_ = self.get_derivatives(tf.zeros_like(t))
#        
        u3 = u0 - self.x_init
        u4 = v0  - self.y_init

        return u1,u2,u3,u4
        
    def loss(self,t):
        u1,u2,u3,u4 = self.ode_ic(t)
        mse_x  = tf.reduce_mean(tf.square(u1))
        mse_y  = tf.reduce_mean(tf.square(u2))
        mse_x0 = tf.reduce_mean(tf.square(u3))
        mse_y0 = tf.reduce_mean(tf.square(u4))
        print(f'mse_x :{mse_x}, mse_y : {mse_y}')
        print('Same order as bc')
        print(f'mse_x0 :{mse_x0}, mse_y0 : {mse_y0}')
        return mse_x+mse_y+mse_x0+mse_y0
    
    def make_flat(self,gradients):
        shapes = tf.shape_n(gradients)
        length_shapes = len(shapes)
        count = 0
        idx = []
        part = []
        for i in range(length_shapes):
            n = np.product(shapes[i])
            idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
            count += n   
            part.extend([i]*n)

        flattened =  tf.math.abs(tf.dynamic_stitch(idx, gradients))
        return flattened
    
    def calc_lambda_hat(self, grad_residue_x,grad_residue_x_ic):
        eps = tf.constant(1e-15, tf.float32)
        numerator     = tf.reduce_max(tf.math.abs(grad_residue_x))
        denominator   = tf.math.abs(grad_residue_x_ic)
        denominator   = tf.math.reduce_mean(denominator)
        return tf.cast(numerator/(denominator+eps),tf.float32)
    
    @tf.function
    def loss_and_update(self,t):
        lsso = []
#         n_ic = tf.constant(2, tf.int32)
#         lambdas = tf.Variable(tf.ones(n_ic))
#         lambdas_hat = tf.Variable(tf.zeros(n_ic))
        alpha = tf.constant(0.9, tf.float32)
        eta = tf.constant(10**(-3), tf.float32)
        
        with tf.GradientTape(persistent=True) as tape:
            u1,u2,u3,u4 = self.ode_ic(t)
            mse_x  = tf.reduce_mean(tf.square(u1))
            mse_y  = tf.reduce_mean(tf.square(u2))
            mse_x0 = tf.reduce_mean(tf.square(u3))
            mse_y0 = tf.reduce_mean(tf.square(u4))
            
        grad_residue_x = tape.gradient(mse_x, self.model.trainable_variables)
        grad_residue_x_ic = tape.gradient(mse_x0, self.model.trainable_variables)
        
        grad_residue_y = tape.gradient(mse_y, self.model.trainable_variables)
        grad_residue_y_ic = tape.gradient(mse_y0, self.model.trainable_variables)     
        del tape 
        
        
        
        
#         print(f' Initalloss :{self.loss(t)}')
        total_n = len(tf.shape_n(self.model.trainable_variables))
        for n in range(total_n):
            
            lambdas_hat[0].assign(self.calc_lambda_hat(grad_residue_x[n],grad_residue_x_ic[n]))
            lambdas[0].assign((1. - alpha)*lambdas[0] + alpha*lambdas_hat[0])
            
            lambdas_hat[1].assign(self.calc_lambda_hat(grad_residue_y[n],grad_residue_y_ic[n]))
            lambdas[1].assign((1. - alpha)*lambdas[1] + alpha*lambdas_hat[1])
            
            loss_x = mse_x + lambdas[0]*mse_x0
            loss_y = mse_y + lambdas[1]*mse_y0
            
            loss_total = loss_x + loss_y 
            weight_b4 = self.model.trainable_variables[n]
            update = eta*(grad_residue_x[n] + lambdas[0]*grad_residue_x_ic[n] + grad_residue_y[n]+lambdas[1]*grad_residue_y_ic[n])
            self.model.trainable_variables[n].assign_sub(update)
            lsso.append(loss_total)
            weight_after = self.model.trainable_variables[n]
        return weight_b4,weight_after
            
#
        
        
#         return mse_x,mse_x0,grad_residue_x,grad_residue_x_ic,mse_y,mse_y0,grad_residue_y,grad_residue_y_ic
            
    
#     @tf.function
#     def loss_and_update(self,t):
#         with tf.GradientTape() as tape:
#             los  = self.loss(t)
#         dlossdpa = tape.gradient(los,self.model.trainable_variables) 
#         self.optim.apply_gradients(zip(dlossdpa, self.model.trainable_variables))
#         return los
    
    def train_with_adam(self,batch_mode,epochs,batch_size,t):
        @tf.function
        def train_and_update(t):
    #         print(f'params : \n {self.model.trainable_variables}')
            with tf.GradientTape() as tape:
#                 tape.watch(model.trainable_variables)
#                 los  = self.loss(t)   Original
                los  = self.loss_and_update(t)   #Modified

            dlossdpa = tape.gradient(los,self.model.trainable_variables) 
            self.optim.apply_gradients(zip(dlossdpa, self.model.trainable_variables))
#             print(f'\n Loss after update :{self.loss(t).numpy()}\n')
            return los
        
        def train_and_update_batch(epochs, batch_size,t):
            loss_batch = []
            loss_decrease = []
            steps_per_epoch = int(t.shape[0]/batch_size)
            
            initial_loss = train_and_update(t).numpy()
            best_so_far = np.inf
#             print(f'initial loss : {initial_loss}\n')
            loss_batch.append(initial_loss)
            
            for epoch in tnrange(epochs, desc= 'EPOCHS'):
                for i in range(steps_per_epoch):
                    t_batch = t[i*batch_size:batch_size*(i+1)]
                    loss = train_and_update(t_batch).numpy()
                    
                    
                    if loss < loss_batch[-1]:
                        if loss < best_so_far:
                            best_so_far = loss
                            loss_decrease.append(loss)
                            self.model.save_weights('best_model_batch')
                            
                    loss_batch.append(loss)  
                    
                if epoch%1000==0:   
                    print(f'\n loss for epoch {epoch} : {loss}  best so far {best_so_far}')  
            print(f'Final loss : {loss} best so far {best_so_far}')    
            return loss_batch,loss_decrease      
                        
                        
        def train_whole_set(t):                
            losses =[]
            loss_decrease = []
            check_decrease = 0
            initial_loss = train_and_update(t).numpy()
            best_so_far =  np.inf
            print(f'initial loss : {initial_loss}')
            losses.append(initial_loss)

            for epoch in tnrange(epochs):
                loss = train_and_update(t).numpy()
                
                if loss < losses[-1]:
                    if loss < best_so_far:
                        best_so_far = loss
                        loss_decrease.append(loss)
                        self.model.save_weights('best_model')
                        check_decrease = loss
                        
                losses.append(loss)
                        
                    
                    
                if epoch%1000==0:
                    print(f'loss for epoch {epoch} : {loss} best so far {best_so_far}') 
            #         print(end = ".")
            
            self.model.load_weights('best_model')
            train_lbfgs(self.model,train_and_update)
            
#             print(f'Final loss : {loss}  best so far {best_so_far}') 
#             print(f'Last decrease : {check_decrease}')
            return losses,loss_decrease
        
        if batch_mode == True:
            losses,loss_decrease = train_and_update_batch(epochs, batch_size,t)
        else:
            losses,loss_decrease = train_whole_set(t)
            
        return losses , loss_decrease  
    
def train_lbfgs(model,loss):
    # Quasi Newton to improve the result : model == updated model
    print(f'\n Initial loss : {loss(t)}')
    shapes = tf.shape_n(model.trainable_variables)
    length_shapes = len(shapes)
    count = 0
    idx = []
    part = []
    for i in range(length_shapes):
        n = np.product(shapes[i])
        idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
        count += n   
        part.extend([i]*n)

    def update_weights(OneD):
        params = tf.dynamic_partition(OneD, part, length_shapes)
        for i, (shape, param) in enumerate(zip(shapes, params)):
            model.trainable_variables[i].assign(tf.reshape(param, shape))

    def flatten_the_parameters(weights):
        return tf.dynamic_stitch(idx, weights) 

    @tf.function
    def value_and_gradient(flat_weights):
        #update weights 
        update_weights(flat_weights)
        with tf.GradientTape() as g:
            los = loss(t)

        grad = g.gradient(los, model.trainable_variables) 
        flattend_grad = flatten_the_parameters(grad) #converts from multDim to 1D
        return los, flattend_grad

    start_time2 = time.time()

    flat_parameters = flatten_the_parameters(model.trainable_variables)
    start = tf.constant(flat_parameters)  # Starting point for the search.
    grads_lists = []
    optim_results = tfp.optimizer.lbfgs_minimize(
      value_and_gradient, initial_position=start, tolerance=1.0e-20, max_iterations=5000)
    grad_curr = tf.norm(optim_results.objective_gradient,ord=np.inf)
    grads_lists.append(grad_curr)

    while  optim_results.converged.numpy() == False:
        optim_results = tfp.optimizer.lbfgs_minimize(
      value_and_gradient, initial_position=start, max_iterations=5000)
        print('converged:', optim_results.converged.numpy())
        print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
        print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
        print('')
        new_grad = tf.norm(optim_results.objective_gradient,ord=np.inf)

        if new_grad == grads_lists[-1]:
            break



    print('converged:', optim_results.converged.numpy())
    print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
    print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
    update_weights(optim_results.position)

#         print('initial loss',initial_loss_after)
    print('loss',loss(t))
    print('Times : ',time.time()-start_time2,'\n')

# %%
optim = tf.keras.optimizers.Adam()
# epochs = 5000
epochs = 5000
batch = 100
x_int = tf.constant(1.0, dtype = tf.float32)
y_int = tf.constant(0.0, dtype = tf.float32)

z_init = tf.constant(np.array([x_int,y_int]), dtype=tf.float32)
# New idea z = [x,y]
pinn = PINN(t, z_hat,z_init,optim)

pinn.loss_and_update(t)

# start = time.time()
# losss,loss_decrease =  pinn.train_with_adam(batch_mode=False,epochs=epochs,batch_size=batch,t=t)
# print(f'Total time {time.time() -start} s')
# Out:
# (<tf.Tensor: shape=(30,), dtype=float32, numpy=
#  array([ 1.01522770e+10,  6.63976673e+10, -1.55936784e+11,  1.60394297e+11,
#          2.19530658e+11, -1.68834990e+11, -9.04515338e+10, -2.00532820e+11,
#          1.49642496e+10,  4.88405033e+10, -1.15733103e+11, -2.82431554e+11,
#          1.59379653e+11, -2.12546454e+11, -3.40948943e+11,  1.43348761e+11,
#          2.89668104e+11, -6.23555625e+10,  1.80125630e+11,  9.36211825e+10,
#         -1.02369993e+11, -1.28986554e+11, -1.82162866e+11,  3.32243239e+11,
#         -2.33219949e+11, -2.67392631e+11,  1.36588345e+11, -1.39426398e+11,
#         -7.23221053e+10,  1.52051270e+11], dtype=float32)>,
#  <tf.Tensor: shape=(30,), dtype=float32, numpy=
#  array([ 1.01522770e+10,  6.63976673e+10, -1.55936784e+11,  1.60394297e+11,
#          2.19530658e+11, -1.68834990e+11, -9.04515338e+10, -2.00532820e+11,
#          1.49642496e+10,  4.88405033e+10, -1.15733103e+11, -2.82431554e+11,
#          1.59379653e+11, -2.12546454e+11, -3.40948943e+11,  1.43348761e+11,
#          2.89668104e+11, -6.23555625e+10,  1.80125630e+11,  9.36211825e+10,
#         -1.02369993e+11, -1.28986554e+11, -1.82162866e+11,  3.32243239e+11,
#         -2.33219949e+11, -2.67392631e+11,  1.36588345e+11, -1.39426398e+11,
#         -7.23221053e+10,  1.52051270e+11], dtype=float32)>)

# %%
# True solutions
x_true = lambda t : tf.math.cos(t)
y_true = lambda t : tf.math.sin(t)

plt.plot(t, x_true(t) ,label = 'real')
plt.plot(t,  y_true(t), label = 'imag')
plt.legend()

# %%
plt.plot(t, x_true(t) ,label = 'Real_soln')
plt.plot(t, z_hat(t)[:,0:1], label = 'NN_soln')
plt.legend()

plt.plot(t, y_true(t) ,label = 'Imag_soln')
plt.plot(t, z_hat(t)[:,1:], label = 'NN_soln')
plt.legend()

# %%
pinn.loss_and_update(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=8.072493e-09>

# %%
plt.plot(loss_decrease)

# %%
optim = tf.keras.optimizers.Adam()
batch = 100
# optim = tf.keras.optimizers.Adam(lr)
pinn = PINN(t, z_hat,z_init,optim)
start = time.time()
losss,l_decrease =  pinn.train_with_adam(batch_mode=True,epochs=epochs,batch_size=batch,t=t)
print(f'final loss {losss[-1]} in is {(time.time() -start)//60.}s ')
# Out:
# Tensor("Mean:0", shape=(), dtype=float32) Tensor("mul_3:0", shape=(), dtype=float32)
# Tensor("Mean_1:0", shape=(), dtype=float32) Tensor("mul_4:0", shape=(), dtype=float32)
# EPOCHS:   0%|          | 0/5000 [00:00<?, ?it/s]
# Tensor("Mean:0", shape=(), dtype=float32) Tensor("mul_3:0", shape=(), dtype=float32)
# Tensor("Mean_1:0", shape=(), dtype=float32) Tensor("mul_4:0", shape=(), dtype=float32)
#
#  loss for epoch 0 : 1.0601245776342694e-05  best so far 1.3244396086520283e-06
#
#  loss for epoch 1000 : 4.114645707886666e-05  best so far 1.1410566713720982e-07
#
#  loss for epoch 2000 : 4.91691826027818e-05  best so far 1.1410566713720982e-07
#
#  loss for epoch 3000 : 8.58152488945052e-05  best so far 1.1410566713720982e-07
#
#  loss for epoch 4000 : 9.695629705674946e-05  best so far 1.1410566713720982e-07
# Final loss : 2.380996556894388e-05 best so far 1.1410566713720982e-07
# final loss 2.380996556894388e-05 in is 4.0s

# %%
optim = tf.keras.optimizers.Adam()
x_int = tf.constant(1.0, dtype = tf.float32)
y_int = tf.constant(0.0, dtype = tf.float32)
z_init = tf.constant(np.array([x_int,y_int]), dtype=tf.float32)
# New idea z = [x,y]
pinn = PINN(t, z_hat,z_init,optim)
# mse_x,mse_x0,grad_residue_x,grad_residue_x_ic,mse_y,mse_y0,grad_residue_y,grad_residue_y_ic = pinn.loss_and_train(t)
# print(len(tf.shape_n(grad_residue_x)),len(tf.shape_n(grad_residue_x_ic)))

# %%
pinn.loss(t)
# Out:
# mse_x :0.5908356308937073, mse_y : 0.44380927085876465
# Same order as bc
# mse_x0 :1.0414159297943115, mse_y0 : 0.0010826740181073546
# <tf.Tensor: shape=(), dtype=float32, numpy=2.0771434>

# %%
pinn.loss_and_update(t)
# Out:
# mse_x :Tensor("Mean_4:0", shape=(), dtype=float32), mse_y : Tensor("Mean_5:0", shape=(), dtype=float32)
# Same order as bc
# mse_x0 :Tensor("Mean_6:0", shape=(), dtype=float32), mse_y0 : Tensor("Mean_7:0", shape=(), dtype=float32)
#  Final loss :Tensor("add_18:0", shape=(), dtype=float32)
# Tensor("Mean:0", shape=(), dtype=float32) Tensor("mul_4:0", shape=(), dtype=float32)
# Tensor("Mean_1:0", shape=(), dtype=float32) Tensor("mul_5:0", shape=(), dtype=float32)
# <tf.Tensor: shape=(), dtype=float32, numpy=3.3577273>

# %%
f = pinn.loss(t)
# Out:
# mse_x :0.5908356308937073, mse_y : 0.44380927085876465
# Same order as bc
# mse_x0 :1.0414159297943115, mse_y0 : 0.0010826740181073546

# %%
losses =[]
loss_decrease = []
check_decrease = 0
initial_loss = pinn.loss_and_update(t).numpy()
best_so_far =  np.inf
print(f'initial loss : {initial_loss}')
losses.append(initial_loss)
epochs = 2000

for epoch in tnrange(epochs):
    loss = pinn.loss_and_update(t).numpy()

    if loss < losses[-1]:
        if loss < best_so_far:
            print('loss',loss)
            best_so_far = loss
            loss_decrease.append(loss)
            self.model.save_weights('best_model')
            check_decrease = loss

    losses.append(loss)



    if epoch%1000==0:
        print(f'loss for epoch {epoch} : {loss} best so far {best_so_far}') 
#         print(end = ".")
# Out:
# initial loss : 3.357727289199829
#   0%|          | 0/2000 [00:00<?, ?it/s]
# loss for epoch 0 : 3.357727289199829 best so far inf
# loss for epoch 1000 : 3.357727289199829 best so far inf

# %%
bone[0].assign(2.)
# Out:
# <tf.Variable 'UnreadVariable' shape=(2,) dtype=float32, numpy=array([2., 0.], dtype=float32)>

# %%
def calc_lambda_hat(grad_residue_x,grad_residue_x_ic):
    numerator     = tf.reduce_max(tf.math.abs(grad_residue_x))
    denominator   = tf.math.abs(grad_residue_x_ic)
    denominator   = tf.math.reduce_mean(denominator)
    return numerator/(denominator_1+1e-15)

# %%
# Out:
# mse_x :0.09700405597686768, mse_y : 0.10311828553676605
# Same order as bc
# mse_x0 :0.9976503849029541, mse_y0 : 4.787502984981984e-05
# <tf.Tensor: shape=(), dtype=float32, numpy=1.1978207>

# %%
n_ic = 2
lambdas = np.ones(n_ic)
lambdas_hat = np.zeros(n_ic)
total_n = len(tf.shape_n(grad_residue_x))
alpha = 0.9
eta = 10**(-3)
print(f' Initalloss :{pinn.loss(t)}')
for n in range(total_n):
    for i in range(n_ic):
        lambdas_hat[i] = calc_lambda_hat(grad_residue_x[n],grad_residue_x_ic[n])
        lambdas[i] = (1. - alpha)*lambdas[i] + alpha*lambdas_hat[i]
#     print(n,lambdas)  
    
#     print(mse_x.numpy(),lambdas[0]*mse_x0.numpy())
#     print(mse_y.numpy(),lambdas[1]*mse_y0.numpy())
    theta_update = eta*(grad_residue_x[n]+grad_residue_y[n] +lambdas[0]*mse_x0 + lambdas[1]*mse_y0)
    
#     print(theta_update)
    pinn.model.trainable_variables[n].assign_sub(theta_update)
# Out:
# mse_x :0.09700405597686768, mse_y : 0.10311828553676605
# Same order as bc
# mse_x0 :0.9976503849029541, mse_y0 : 4.787502984981984e-05
#  Initalloss :1.1978206634521484

# %%
pinn.loss(t)
# Out:
# mse_x :0.07364708930253983, mse_y : 0.07309948652982712
# Same order as bc
# mse_x0 :0.993664562702179, mse_y0 : 5.491468255058862e-05
# <tf.Tensor: shape=(), dtype=float32, numpy=1.1404661>

# %%
 def train_lbfgs(model,loss):
        # Quasi Newton to improve the result : model == updated model
        print(f'\n Initial loss : {loss(t)}')
        shapes = tf.shape_n(model.trainable_variables)
        length_shapes = len(shapes)
        count = 0
        idx = []
        part = []
        for i in range(length_shapes):
            n = np.product(shapes[i])
            idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
            count += n   
            part.extend([i]*n)

        def update_weights(OneD):
            params = tf.dynamic_partition(OneD, part, length_shapes)
            for i, (shape, param) in enumerate(zip(shapes, params)):
                model.trainable_variables[i].assign(tf.reshape(param, shape))

        def flatten_the_parameters(weights):
            return tf.dynamic_stitch(idx, weights) 

        @tf.function
        def value_and_gradient(flat_weights):
            #update weights 
            update_weights(flat_weights)
            with tf.GradientTape() as g:
                los = loss(t)

            grad = g.gradient(los, model.trainable_variables) 
            flattend_grad = flatten_the_parameters(grad) #converts from multDim to 1D
            return los, flattend_grad

        start_time2 = time.time()

        flat_parameters = flatten_the_parameters(model.trainable_variables)
        start = tf.constant(flat_parameters)  # Starting point for the search.
        grads_lists = []
        optim_results = tfp.optimizer.lbfgs_minimize(
          value_and_gradient, initial_position=start, tolerance=1.0e-20, max_iterations=5000)
        grad_curr = tf.norm(optim_results.objective_gradient,ord=np.inf)
        grads_lists.append(grad_curr)

        while  optim_results.converged.numpy() == False:
            optim_results = tfp.optimizer.lbfgs_minimize(
          value_and_gradient, initial_position=start, max_iterations=5000)
            print('converged:', optim_results.converged.numpy())
            print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
            print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
            print('')
            new_grad = tf.norm(optim_results.objective_gradient,ord=np.inf)
           
            if new_grad == grads_lists[-1]:
                break
                

            
        print('converged:', optim_results.converged.numpy())
        print(f'num_iterations {optim_results.num_iterations} and evaluations {optim_results.num_objective_evaluations}')
        print(f'gradient:{tf.norm(optim_results.objective_gradient,ord=np.inf)}')
        update_weights(optim_results.position)
        
#         print('initial loss',initial_loss_after)
        print('loss',loss(t))
        print('Times : ',time.time()-start_time2,'\n')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_28198/649466228.py in <module>
# ----> 1 pinn.loss_and_train(t)
#
# /tmp/ipykernel_28198/1975612274.py in loss_and_train(self, t)
#      91         grad_l_x = tape.gradient(mse_x, self.model.trainable_variables)
#      92
# ---> 93         return self.make_flat(grad_l_x)
#      94
#      95
#
# TypeError: make_flat() takes 1 positional argument but 2 were given

# %%
def make_flat(tt):
    shapes = tf.shape_n(tt)
    length_shapes = len(shapes)
    count = 0
    idx = []
    part = []
    for i in range(length_shapes):
        n = np.product(shapes[i])
        idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
        count += n   
        part.extend([i]*n)
        
    return tf.dynamic_stitch(idx, tt)

# %%
make_flat(pinn.loss_and_train(t))
# Out:
# <tf.Tensor: shape=(4224,), dtype=float32, numpy=
# array([ 0.05097177,  0.0190041 , -0.01036751, ...,  0.25193268,
#        -0.23140165, -0.16424909], dtype=float32)>

# %%
tt = pinn.loss_and_train(t)
shapes = tf.shape_n(tt)
length_shapes = len(shapes)
count = 0
idx = []
part = []
for i in range(length_shapes):
    n = np.product(shapes[i])
    idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
    count += n   
    part.extend([i]*n)
    
def flatten_the_parameters(weights):
    return tf.dynamic_stitch(idx, weights)

# %%
tf.reduce_max(flatten_the_parameters(tt))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.6474507>

# %%
optim = tf.keras.optimizers.Adam()
# epochs = 5000
epochs = 1000
batch = 100
x_int = tf.constant(1.0, dtype = tf.float32)
y_int = tf.constant(0.0, dtype = tf.float32)

z_init = tf.constant(np.array([x_int,y_int]), dtype=tf.float32)
# New idea z = [x,y]
pinn = PINN(t, z_hat,z_init,optim)

# %%
pinn.loss(t)
# Out:
# mse_x :1.952274715222302e-06, mse_y : 1.3218915455581737e-06
# Same order as bc
# mse_x0 :7.16369186193333e-11, mse_y0 : 2.1797640670229157e-07
# <tf.Tensor: shape=(), dtype=float32, numpy=3.4922143e-06>

# %%
# batch_mode=False means without batches
start = time.time()
losss,loss_decrease =  pinn.train_with_adam(batch_mode=False,epochs=epochs,batch_size=batch,t=t)
print(f'final loss {losss[-1]} in {time.time() -start} s')
# Out:
# mse_x :Tensor("Mean:0", shape=(), dtype=float32), mse_y : Tensor("Mean_1:0", shape=(), dtype=float32)
# Same order as bc
# mse_x0 :Tensor("Mean_2:0", shape=(), dtype=float32), mse_y0 : Tensor("Mean_3:0", shape=(), dtype=float32)
# mse_x :Tensor("Mean:0", shape=(), dtype=float32), mse_y : Tensor("Mean_1:0", shape=(), dtype=float32)
# Same order as bc
# mse_x0 :Tensor("Mean_2:0", shape=(), dtype=float32), mse_y0 : Tensor("Mean_3:0", shape=(), dtype=float32)
# initial loss : 0.0001353822008240968
#   0%|          | 0/1000 [00:00<?, ?it/s]
# loss for epoch 0 : 0.10675888508558273 best so far inf
#
#  Initial loss : 1.5822425893929903e-06
# converged: False
# num_iterations 6 and evaluations 124
# gradient:0.0002178708091378212
#
# converged: False
# num_iterations 6 and evaluations 124
# gradient:0.0002178708091378212
# mse_x :1.106280365092971e-06, mse_y : 3.706169025008421e-07
# Same order as bc
# mse_x0 :5.658208568348755e-09, mse_y0 : 1.0967906582948217e-09
# loss tf.Tensor(1.4836522e-06, shape=(), dtype=float32)
# Times :  9.033079862594604
#
# Final loss : 1.5997757145669311e-06  best so far 1.4756283235328738e-06
# Last decrease : 1.4756283235328738e-06
# final loss 1.5997757145669311e-06 in 27.607057809829712 s

# %%
pinn.loss(t)
# Out:
# mse_x :1.1797870911323116e-06, mse_y : 5.093806407785451e-07
# Same order as bc
# mse_x0 :9.698072744868114e-07, mse_y0 : 1.391619175450387e-08
# <tf.Tensor: shape=(), dtype=float32, numpy=2.6728912e-06>

# %%
pinn.loss_and_update(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=2.6728912e-06>

# %%
plt.plot(loss_decrease)

# %%
pinn.loss_and_update(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0012443173>

# %%
z_hat.load_weights('best_model')
pinn_best.loss_and_update(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.00085711956>

# %%
z_hat.load_weights('best_model')
pinn_best = PINN(t, z_hat,z_init,optim)
pinn_best.loss(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=9.796349e-07>

# %%
pinn_best.loss_and_update(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.00027069508>

# %%
z_hat.trainable_variables[:1]
# Out:
# [<tf.Variable 'my_dense/kernel:0' shape=(1, 20) dtype=float32, numpy=
#  array([[ 0.21066287,  1.1495037 ,  0.70347065, -1.4267414 ,  1.611674  ,
#           1.8663243 ,  0.8817898 , -2.1386323 , -0.9937933 , -0.88408947,
#          -0.7090262 , -0.04465394, -2.9553294 ,  0.8862563 ,  3.1053386 ,
#          -0.8882362 , -0.8503369 ,  1.2180309 ,  1.0870193 ,  2.0011735 ]],
#        dtype=float32)>]

# %%
l_hat = PINN(t, z_hat,z_init,optim).loss_and_update(t)
l_hat
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=5.9327056e-07>

# %%
model = z_hat

# %%
pinn = PINN(t, model,z_init,optim)
pinn.loss(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.00012709646>

# %%
train_lbfgs(model,pinn)
# Out:
# Initial loss : 0.00012709645670838654
# converged: False
# num_iterations 20 and evaluations 168
# gradient:0.00016305777535308152
# converged: False
# num_iterations 20 and evaluations 168
# gradient:0.00016305777535308152
# loss tf.Tensor(2.415467e-07, shape=(), dtype=float32)
# 6.695822715759277

# %%
pinn.loss(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=4.003242e-07>

# %%
        # Quasi Newton to improve the result : model == updated model
model =  z_hat  

shapes = tf.shape_n(model.trainable_variables)
length_shapes = len(shapes)
count = 0
idx = []
part = []
for i in range(length_shapes):
    n = np.product(shapes[i])
    idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
    count += n   
    part.extend([i]*n)

# %%
def update_weights(OneD):
    params = tf.dynamic_partition(OneD, part, length_shapes)
    for i, (shape, param) in enumerate(zip(shapes, params)):
        model.trainable_variables[i].assign(tf.reshape(param, shape))
        
def flatten_the_parameters(weights):
    return tf.dynamic_stitch(idx, weights)         

@tf.function
def value_and_gradient(flat_weights):
    #update weights 
    update_weights(flat_weights)
    with tf.GradientTape() as g:
        los = PINN(t, model,z_init,optim).loss(t)
    grad = g.gradient(los, model.trainable_variables) 
    flattend_grad = flatten_the_parameters(grad) #converts from multDim to 1D
    return los, flattend_grad

# %%
test = False

# %%
optim_results.objective_value
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.6511901e-06>

# %%
shapes = tf.shape_n(model.trainable_variables)
length_shapes = len(shapes)
count = 0
idx = []
part = []
for i in range(length_shapes):
    n = np.product(shapes[i])
    idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32),shapes[i]))
    count += n   
    part.extend([i]*n)
    
def flatten_the_parameters(weights):
    return tf.dynamic_stitch(idx, weights) 
oneD = flatten_the_parameters(model.trainable_variables)

# %%
def update_weights(OneD):
    params = tf.dynamic_partition(OneD, part, length_shapes)
    for i, (shape, param) in enumerate(zip(shapes, params)):
        model.trainable_variables[i].assign(tf.reshape(param, shape))

# %%
update_weights(oneD)

# %%
# True solutions
x_true = lambda t : tf.math.cos(t)
y_true = lambda t : tf.math.sin(t)

plt.plot(t, x_true(t) ,label = 'real')
plt.plot(t,  y_true(t), label = 'imag')
plt.legend()

# %%
plt.plot(t, x_true(t) ,label = 'Real_soln')
plt.plot(t, z_hat(t)[:,0:1], label = 'NN_soln')
plt.legend()

# %%
plt.plot(t, y_true(t) ,label = 'Imag_soln')
plt.plot(t, z_hat(t)[:,1:], label = 'NN_soln')
plt.legend()

# %%
# With batches
# lr = tf.keras.optimizers.schedules.PiecewiseConstantDecay([1000,3000],[1e-2,1e-3,5e-4])
optim = tf.keras.optimizers.Adam()
batch = 10
# optim = tf.keras.optimizers.Adam(lr)
pinn = PINN(t, z_hat,z_init,optim)
start = time.time()
losss,l_decrease =  pinn.train_with_adam(batch_mode=True,epochs=epochs,batch_size=batch,t=t)
print(f'final loss {losss[-1]} in is {(time.time() -start)//60.}s ')
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function PINN.train_with_adam.<locals>.train_and_update at 0x7fed1576c280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# EPOCHS:   0%|          | 0/5000 [00:00<?, ?it/s]
# steps_per_epoch:   0%|          | 0/200 [00:00<?, ?it/s]
#  loss for epoch 0 : 3.620007919380441e-05  best so far 1.6595345186942723e-07
# steps_per_epoch:   0%|          | 0/200 [00:00<?, ?it/s]
# steps_per_epoch:   0%|          | 0/200 [00:00<?, ?it/s]
# steps_per_epoch:   0%|          | 0/200 [00:00<?, ?it/s]
# steps_per_epoch:   0%|          | 0/200 [00:00<?, ?it/s]
# steps_per_epoch:   0%|          | 0/200 [00:00<?, ?it/s]
# steps_per_epoch:   0%|          | 0/200 [00:00<?, ?it/s]
# steps_per_epoch:   0%|          | 0/200 [00:00<?, ?it/s]
# steps_per_epoch:   0%|          | 0/200 [00:00<?, ?it/s]
# steps_per_epoch:   0%|          | 0/200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17289/3468604580.py in <module>
#       6 pinn = PINN(t, z_hat,z_init,optim)
#       7 start = time.time()
# ----> 8 losss,l_decrease =  pinn.train_with_adam(batch_mode=True,epochs=epochs,batch_size=batch,t=t)
#       9 print(f'final loss {losss[-1]} in is {(time.time() -start)//60.}s ')
#
# /tmp/ipykernel_17289/1176337105.py in train_with_adam(self, batch_mode, epochs, batch_size, t)
#     150
#     151         if batch_mode == True:
# --> 152             losses,loss_decrease = train_and_update_batch(epochs, batch_size,t)
#     153         else:
#     154             losses,loss_decrease = train_whole_set(t)
#
# /tmp/ipykernel_17289/1176337105.py in train_and_update_batch(epochs, batch_size, t)
#      97             for epoch in tnrange(epochs, desc= 'EPOCHS'):
#      98                 for i in tnrange(steps_per_epoch, desc= 'steps_per_epoch'):
# ---> 99                     t_batch = t[i*batch_size:batch_size*(i+1)]
#     100                     loss = train_and_update(t_batch).numpy()
#     101
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#    1069       skip_on_eager=False) as name:
#    1070     if begin:
# -> 1071       packed_begin, packed_end, packed_strides = (stack(begin), stack(end),
#    1072                                                   stack(strides))
#    1073       # TODO(mdan): Instead of implicitly casting, it's better to enforce the
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py in stack(values, axis, name)
#    1466     try:
#    1467       # If the input is a constant list, it can be converted to a constant op
# -> 1468       return ops.convert_to_tensor(values, name=name)
#    1469     except (TypeError, ValueError, NotImplementedError):
#    1470       pass  # Input list contains non-constant tensors
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1636
#    1637     if ret is None:
# -> 1638       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1639
#    1640     if ret is NotImplemented:
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     341                                          as_ref=False):
#     342   _ = as_ref
# --> 343   return constant(v, dtype=dtype, name=name)
#     344
#     345
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#     269
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277       with trace.Trace("tf.constant"):
#     278         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 279     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     280
#     281   g = ops.get_default_graph()
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     302 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     303   """Creates a constant on the current device."""
# --> 304   t = convert_to_eager_tensor(value, ctx, dtype)
#     305   if shape is None:
#     306     return t
#
# ~/miniconda3/envs/tf_38gpu/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# KeyboardInterrupt:

# %%
# PINN(t, z_hat.load_weights('best_model_batch'),z_init,optim).loss_and_update(t)
z_hat.weights[:5]
# Out:
# [<tf.Variable 'normalization_5/mean:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>,
#  <tf.Variable 'normalization_5/variance:0' shape=(1,) dtype=float32, numpy=array([1.], dtype=float32)>,
#  <tf.Variable 'normalization_5/count:0' shape=() dtype=int64, numpy=0>,
#  <tf.Variable 'my_dense_55/kernel:0' shape=(1, 20) dtype=float32, numpy=
#  array([[-1.5554392e+00, -1.7736527e-01,  1.5103796e-01, -5.8755237e-01,
#          -1.1771456e+00,  1.0198765e+00, -1.7474394e-03, -2.5685458e+00,
#          -1.4984719e+00,  2.5542572e-01, -3.4463957e-01, -6.5993458e-01,
#           3.4298164e-01,  1.0376801e-02, -2.0547895e+00, -1.3275676e-03,
#          -6.0675899e-03,  9.6742016e-01, -8.6651844e-01, -2.2441779e-01]],
#        dtype=float32)>,
#  <tf.Variable 'my_dense_55/bias:0' shape=(20,) dtype=float32, numpy=
#  array([-1.95472062e-01, -7.87981004e-02, -4.26351056e-02,  3.48284841e-02,
#         -1.09242156e-01,  4.68453169e-02, -2.17188150e-02, -4.34710562e-01,
#         -6.47150576e-01,  5.53319119e-02, -9.45017859e-03,  1.73608083e-02,
#         -8.87612104e-02, -8.77335481e-03, -3.13315332e-01, -1.58684626e-02,
#          1.40321252e-04, -1.37106806e-01,  2.62822598e-01,  3.53103392e-02],
#        dtype=float32)>]

# %%
z_hat.load_weights('best_model_batch')
z_hat.weights[:5]
# Out:
# [<tf.Variable 'normalization_5/mean:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>,
#  <tf.Variable 'normalization_5/variance:0' shape=(1,) dtype=float32, numpy=array([1.], dtype=float32)>,
#  <tf.Variable 'normalization_5/count:0' shape=() dtype=int64, numpy=0>,
#  <tf.Variable 'my_dense_55/kernel:0' shape=(1, 20) dtype=float32, numpy=
#  array([[-1.5554392e+00, -1.7736527e-01,  1.5103796e-01, -5.8755237e-01,
#          -1.1771456e+00,  1.0198765e+00, -1.7474394e-03, -2.5685458e+00,
#          -1.4984719e+00,  2.5542572e-01, -3.4463957e-01, -6.5993458e-01,
#           3.4298164e-01,  1.0376801e-02, -2.0547895e+00, -1.3275676e-03,
#          -6.0675899e-03,  9.6742016e-01, -8.6651844e-01, -2.2441779e-01]],
#        dtype=float32)>,
#  <tf.Variable 'my_dense_55/bias:0' shape=(20,) dtype=float32, numpy=
#  array([-1.95472062e-01, -7.87981004e-02, -4.26351056e-02,  3.48284841e-02,
#         -1.09242156e-01,  4.68453169e-02, -2.17188150e-02, -4.34710562e-01,
#         -6.47150576e-01,  5.53319119e-02, -9.45017859e-03,  1.73608083e-02,
#         -8.87612104e-02, -8.77335481e-03, -3.13315332e-01, -1.58684626e-02,
#          1.40321252e-04, -1.37106806e-01,  2.62822598e-01,  3.53103392e-02],
#        dtype=float32)>]

# %%
z_hat.weights[:5]
# Out:
# [<tf.Variable 'normalization_5/mean:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>,
#  <tf.Variable 'normalization_5/variance:0' shape=(1,) dtype=float32, numpy=array([1.], dtype=float32)>,
#  <tf.Variable 'normalization_5/count:0' shape=() dtype=int64, numpy=0>,
#  <tf.Variable 'my_dense_55/kernel:0' shape=(1, 20) dtype=float32, numpy=
#  array([[-1.5555440e+00, -1.7678401e-01,  1.5048967e-01, -5.8731502e-01,
#          -1.1771628e+00,  1.0194594e+00, -2.6344997e-03, -2.5671861e+00,
#          -1.4975419e+00,  2.5496012e-01, -3.4451130e-01, -6.5979344e-01,
#           3.4270135e-01,  7.4549569e-03, -2.0541601e+00, -8.6055789e-04,
#          -6.1216513e-03,  9.6689522e-01, -8.6637193e-01, -2.2413905e-01]],
#        dtype=float32)>,
#  <tf.Variable 'my_dense_55/bias:0' shape=(20,) dtype=float32, numpy=
#  array([-1.9569904e-01, -7.9318382e-02, -4.2408284e-02,  3.4586594e-02,
#         -1.0952595e-01,  4.6705928e-02, -2.2372192e-02, -4.3392429e-01,
#         -6.4668590e-01,  5.5202167e-02, -9.8291375e-03,  1.6968103e-02,
#         -8.8488288e-02, -1.1730245e-02, -3.1337327e-01, -1.5183054e-02,
#          8.9408430e-05, -1.3735145e-01,  2.6241687e-01,  3.4991022e-02],
#        dtype=float32)>]

# %%
PINN(t, z_hat,z_init,optim).loss_and_update(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.00012725324>

# %%
z_hat.load_weights('best_model')
pinn = PINN(t, z_hat,z_init,optim)
pinn.loss_and_update(t)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0019619>

# %%
plt.plot(t, y_true(t) ,label = 'Imag_soln')
plt.plot(t, z_hat(t)[:,1:], label = 'NN_soln')
plt.legend()

# %%
np.min(z_hat(t)[:,0:1])
# Out:
# -0.078544706

# %%
plt.plot(t, x_true(t) ,label = 'Real')
plt.plot(t, z_hat(t)[:,0:1], label = 'NN')
# plt.ylim(np.min(z_hat(t)[:,0:1]),)
plt.legend()

# %%
# plt.plot(t, y_true(t) ,label = 'Real')
plt.plot(t, z_hat(t)[:,1:], label = 'NN')
plt.legend()

# %%
x_hat = X_approx(num_of_hid_layers = 3, units_per_layer = 5, num_out=1, initialization = 0,activation = 'mish')
y_hat = Y_approx(num_of_hid_layers = 3, units_per_layer = 5, num_out=1, initialization = 0,activation = 'mish')

# %%
with tf.GradientTape(persistent=True) as tape:
    tape.watch(t) 
    x = x_hat(t)
    y = y_hat(t)
x_prime = tape.gradient(x,t)    
y_prime = tape.gradient(y,t)  
del tape
print(f'x prime {x_prime} \n y_prime {y_prime}')
# Out:
# x prime [[-0.04691141]
#  [-0.04580088]
#  [-0.04488641]
#  [-0.04389558]
#  [-0.043158  ]
#  [-0.04230914]
#  [-0.04150027]
#  [-0.04096917]
#  [-0.04029977]
#  [-0.03980972]
#  [-0.03932826]
#  [-0.03878361]
#  [-0.03844483]
#  [-0.0380714 ]
#  [-0.03777011]
#  [-0.03750508]
#  [-0.03729995]
#  [-0.03701679]
#  [-0.03681608]
#  [-0.03672321]
#  [-0.03664884]
#  [-0.03652166]
#  [-0.03646646]
#  [-0.03636636]
#  [-0.03637227]
#  [-0.03632809]
#  [-0.03634595]
#  [-0.03639278]
#  [-0.03642997]
#  [-0.036442  ]
#  [-0.03648344]
#  [-0.03647701]
#  [-0.03653761]
#  [-0.03662881]
#  [-0.03669764]
#  [-0.03675947]
#  [-0.03684453]
#  [-0.03696074]
#  [-0.03699692]
#  [-0.03705414]
#  [-0.03713073]
#  [-0.03717476]
#  [-0.03723507]
#  [-0.03731408]
#  [-0.03736116]
#  [-0.03742646]
#  [-0.03746198]
#  [-0.03747474]
#  [-0.03752461]
#  [-0.03753534]
#  [-0.03754866]
#  [-0.03752921]
#  [-0.03754056]
#  [-0.03753002]
#  [-0.03750424]
#  [-0.03748228]
#  [-0.0374103 ]
#  [-0.03739306]
#  [-0.03733627]
#  [-0.03725561]
#  [-0.03719684]
#  [-0.03709857]
#  [-0.03701421]
#  [-0.03691789]
#  [-0.03682933]
#  [-0.03666963]
#  [-0.03655115]
#  [-0.03642002]
#  [-0.03627374]
#  [-0.03609196]
#  [-0.03595727]
#  [-0.0357832 ]
#  [-0.03560645]
#  [-0.03542266]
#  [-0.03524411]
#  [-0.03500322]
#  [-0.03479844]
#  [-0.03459103]
#  [-0.03436468]
#  [-0.03415184]
#  [-0.03391324]
#  [-0.03367183]
#  [-0.03343185]
#  [-0.03317185]
#  [-0.03292319]
#  [-0.03265684]
#  [-0.03237683]
#  [-0.03210758]
#  [-0.03182239]
#  [-0.03153836]
#  [-0.0312509 ]
#  [-0.03096159]
#  [-0.03066252]
#  [-0.03038106]
#  [-0.03006693]
#  [-0.02976796]
#  [-0.02945108]
#  [-0.02912945]
#  [-0.02881433]
#  [-0.02849426]]
#  y_prime [[-0.873345  ]
#  [-0.9014929 ]
#  [-0.92947143]
#  [-0.96069384]
#  [-0.9916118 ]
#  [-1.0249698 ]
#  [-1.059465  ]
#  [-1.0953821 ]
#  [-1.1319846 ]
#  [-1.1703027 ]
#  [-1.2101289 ]
#  [-1.2516001 ]
#  [-1.2939574 ]
#  [-1.3385301 ]
#  [-1.3847044 ]
#  [-1.4308811 ]
#  [-1.4783027 ]
#  [-1.5274078 ]
#  [-1.5779964 ]
#  [-1.6279789 ]
#  [-1.6797978 ]
#  [-1.7324792 ]
#  [-1.7862759 ]
#  [-1.8400075 ]
#  [-1.8940868 ]
#  [-1.9495919 ]
#  [-2.0029774 ]
#  [-2.0575037 ]
#  [-2.1125245 ]
#  [-2.165781  ]
#  [-2.2196825 ]
#  [-2.2724025 ]
#  [-2.324757  ]
#  [-2.3757966 ]
#  [-2.4240928 ]
#  [-2.4722633 ]
#  [-2.518731  ]
#  [-2.5631738 ]
#  [-2.6065404 ]
#  [-2.6479537 ]
#  [-2.6862097 ]
#  [-2.721566  ]
#  [-2.7561436 ]
#  [-2.7883463 ]
#  [-2.8172467 ]
#  [-2.8437026 ]
#  [-2.8658965 ]
#  [-2.8882837 ]
#  [-2.9068599 ]
#  [-2.9237094 ]
#  [-2.9352014 ]
#  [-2.9454107 ]
#  [-2.9528065 ]
#  [-2.9577157 ]
#  [-2.9601107 ]
#  [-2.959089  ]
#  [-2.9547155 ]
#  [-2.9496148 ]
#  [-2.941869  ]
#  [-2.9320168 ]
#  [-2.919036  ]
#  [-2.9047735 ]
#  [-2.8872056 ]
#  [-2.8676007 ]
#  [-2.848034  ]
#  [-2.826697  ]
#  [-2.8003073 ]
#  [-2.7773814 ]
#  [-2.7497401 ]
#  [-2.721178  ]
#  [-2.6940136 ]
#  [-2.6623552 ]
#  [-2.6312222 ]
#  [-2.6001077 ]
#  [-2.5671341 ]
#  [-2.534605  ]
#  [-2.4994519 ]
#  [-2.466247  ]
#  [-2.4314673 ]
#  [-2.3994417 ]
#  [-2.364571  ]
#  [-2.3287575 ]
#  [-2.2952769 ]
#  [-2.2607865 ]
#  [-2.2259896 ]
#  [-2.1914146 ]
#  [-2.1567507 ]
#  [-2.12151   ]
#  [-2.0887136 ]
#  [-2.0561304 ]
#  [-2.0239882 ]
#  [-1.9923265 ]
#  [-1.9645844 ]
#  [-1.9305606 ]
#  [-1.9007996 ]
#  [-1.871942  ]
#  [-1.8412747 ]
#  [-1.8134251 ]
#  [-1.7868681 ]
#  [-1.7600766 ]]

# %%
class PINN:
    def __init__(self, t,model_x, model_y, x_init, y_init,optim):
        self.model_x = model_x
        self.model_y = model_y
        
        self.t = t
        self.x_init = x_init
        self.y_init = y_init
        
        self.optim = optim

        
    def get_derivatives(self,t):
        '''
        Calculate the derivatives and function that correspond to the ode

        input:
                t : independent variant

        output:
                value and corresponding derivatives
                
        

        '''
        with tf.GradientTape(persistent=True) as tape:
            tape.watch(t) 
            x = self.model_x(t)
            y = self.model_y(t)
        x_prime = tape.gradient(x,t)    
        y_prime = tape.gradient(y,t)   
        del tape
        
        return x,y,x_prime,y_prime   
        
    def ode_ic(self,t):
        x_hat,y_hat,x_prime,y_prime = self.get_derivatives(self.t)
       
        u1 =  x_prime + x_hat - 6.0*y_hat
        u2 =  y_prime - x_hat + 2.0*y_hat
#         Initial conditions
        x0,y0,x_prime0,y_prime0 = self.get_derivatives(tf.zeros_like(self.t))
#        
        u3 =  x0-self.x_init
        u4 =  y0 - self.y_init

        return u1,u2,u3,u4
        
    def loss(self,t):
        u1,u2,u3,u4 = self.ode_ic(t)
        mse_x  = tf.reduce_mean(tf.square(u1))
        mse_y  = tf.reduce_mean(tf.square(u2))
        mse_x0 = tf.reduce_mean(tf.square(u3))
        mse_y0 = tf.reduce_mean(tf.square(u4))
        return mse_x+mse_y+mse_x0+mse_y0
    
    
    def train_with_adam(self,batch_mode,epochs,batch_size,t):
#         which parameters???
        @tf.function
        def train_and_update(t):
    #         print(f'params : \n {self.model.trainable_variables}')
            with tf.GradientTape() as tape:
                tape.watch(model.trainable_variables)
                los  = self.loss(t)
            dlossdpa = tape.gradient(los,self.model.trainable_variables) 
            self.optim.apply_gradients(zip(dlossdpa, self.model.trainable_variables))
            return los
        
        def train_and_update_batch(epochs, batch_size,t):
            loss_batch = []
            steps_per_epoch = int(t.shape[0]/batch_size)
            
            initial_loss = train_and_update(t).numpy()
            print(f'initial loss : {initial_loss}')
            
            for epoch in range(epochs):
#                 print(f'Epoch {epoch} ', end = ".")
                for i in range(steps_per_epoch):
                    t_batch = t[i*batch_size:batch_size*(i+1)]
                    loss = train_and_update(t_batch).numpy()
                    loss_batch.append(loss)
                    
#                     if i%(steps_per_epoch/10)==0:
#                         print(end=".")
                        
                if epoch%1000==0:   
                    print(f'loss for epoch {epoch} : {loss}')  
            print(f'Final loss : {loss}')    
            return loss_batch      
                        
                        
        def train_whole_set(t):                
            losses =[]
            initial_loss = train_and_update(t).numpy()
            print(f'initial loss : {initial_loss}')
            losses.append(initial_loss)

            for epoch in range(epochs):
            #     print(f'epoch {epoch}')
            #     print('epoch {}'.format(epoch),end = ".")
                loss = train_and_update(t).numpy()
                losses.append(loss)
            #     print(f'loss : {loss}')

                if epoch%1000==0:
                    print(f'loss for epoch {epoch} : {loss}') 
            #         print(end = ".")
            print(f'Final loss : {loss}') 
            return losses
        
        if batch_mode == True:
            losses = train_and_update_batch(epochs, batch_size,t)
        else:
            losses = train_whole_set(t)
            
        return losses

# %%
optim = tf.keras.optimizers.Adam()
epochs = 5000
batch = 10
x_int = tf.constant(2.0, dtype = tf.float32)
y_int = tf.constant(0.0, dtype = tf.float32)


pinn = PINN(t,x_hat, y_hat, x_int, y_int,optim)

# %%
loss_list = pinn.train_with_adam(batch_mode=False,epochs=epochs,batch_size=batch,t=t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_42571/2907977790.py in <module>
# ----> 1 loss_list = pinn.train_with_adam(batch_mode=False,epochs=epochs,batch_size=batch,t=t)
#
# /tmp/ipykernel_42571/1049554588.py in train_with_adam(self, batch_mode, epochs, batch_size, t)
#     113             losses = train_and_update_batch(epochs, batch_size,t)
#     114         else:
# --> 115             losses = train_whole_set(t)
#     116
#     117         return losses
#
# /tmp/ipykernel_42571/1049554588.py in train_whole_set(t)
#      93         def train_whole_set(t):
#      94             losses =[]
# ---> 95             initial_loss = train_and_update(t).numpy()
#      96             print(f'initial loss : {initial_loss}')
#      97             losses.append(initial_loss)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /tmp/__autograph_generated_file32quhzrw.py in tf__train_and_update(t)
#      10                 retval_ = ag__.UndefinedReturnValue()
#      11                 with ag__.ld(tf).GradientTape() as tape:
# ---> 12                     ag__.converted_call(ag__.ld(tape).watch, (ag__.ld(model).trainable_variables,), None, fscope)
#      13                     los = ag__.converted_call(ag__.ld(self).loss, (ag__.ld(t),), None, fscope)
#      14                 dlossdpa = ag__.converted_call(ag__.ld(tape).gradient, (ag__.ld(los), ag__.ld(self).model.trainable_variables), None, fscope)
#
# NameError: in user code:
#
#     File "/tmp/ipykernel_42571/1049554588.py", line 64, in train_and_update  *
#         tape.watch(model.trainable_variables)
#
#     NameError: name 'model' is not defined
